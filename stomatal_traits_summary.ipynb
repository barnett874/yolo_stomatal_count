# %%
def median_region_hits(boxes, img_width, region_width=50, n_trials=10):
    """
    随机在水平范围 [0, img_width-region_width] 采样 n_trials 个起点，
    构造宽度为 region_width 的竖条区域，统计该区域与多少个框水平重叠，
    返回这 n_trials 个命中数的中位数。

    boxes: DataFrame，包含 xmin, xmax（像素）两列
    img_width: 图像宽度（像素）
    region_width: 区域宽度（像素），默认 50
    n_trials: 试验次数，默认 10
    """
    counts = []
    max_start = max(0, img_width - region_width)
    for _ in range(n_trials):
        x0 = np.random.uniform(0, max_start)
        x1 = x0 + region_width
        # 统计水平重叠：boxes.xmin <= x1 且 boxes.xmax >= x0
        hits = ((boxes["xmin"] <= x1) & (boxes["xmax"] >= x0)).sum()
        counts.append(int(hits))
    return float(np.mean(counts))

# %%
def load_yolo_boxes(txt_path, img_w, img_h):
    """
    读取 YOLO 格式的 txt，转换为像素坐标的 box 和中心点
    返回 DataFrame 包含：xmin, ymin, xmax, ymax, x_center, y_center, width, height
    """
    cols = ["cls", "x_c_norm", "y_c_norm", "w_norm", "h_norm"]
    df = pd.read_csv(txt_path, sep=" ", names=cols)
    # 转为像素
    df["x_center"] = df["x_c_norm"] * img_w
    df["y_center"] = df["y_c_norm"] * img_h
    df["width_px"] = df["w_norm"] * img_w
    df["height_px"] = df["h_norm"] * img_h
    df["xmin"] = df["x_center"] - df["width_px"] / 2
    df["ymin"] = df["y_center"] - df["height_px"] / 2
    df["xmax"] = df["x_center"] + df["width_px"] / 2
    df["ymax"] = df["y_center"] + df["height_px"] / 2
    return df[
        [
            "xmin",
            "ymin",
            "xmax",
            "ymax",
            "x_center",
            "y_center",
            "width_px",
            "height_px",
        ]
    ]


def compute_density(n_stomata, img_w, img_h):
    """气孔密度 = 气孔数 / 图像像素面积"""
    area = img_w * img_h
    return n_stomata / area


def count_rows(df, y_tol=None):
    """
    基于 PCA 把气孔中心点旋转到行方向坐标系，再在垂直于行（PC2）方向上聚类统计行数。

    df: 包含 x_center, y_center, height_px 的 DataFrame
    y_tol: 同一行在 PC2 方向上的最大距离阈值（默认用平均高度投影计算）
    """
    # 1. 提取中心坐标
    coords = df[["x_center", "y_center"]].values

    # 2. PCA：第一主成分 PC1 对应行的延伸方向，第二主成分 PC2 正交于行
    pca = PCA(n_components=2).fit(coords)
    # 在 PC2 方向上的投影
    pc2 = pca.transform(coords)[:, 1]

    # 3. 如果用户没给阈值，用平均高度在 PC2 轴上的投影长度做阈值
    if y_tol is None:
        # PC2 方向在原 y 轴分量 = |pca.components_[1,1]|
        proj = abs(pca.components_[1, 1])
        y_tol = df["height_px"].mean() * proj

    # 4. 对投影值排序，跳跃大于阈值时新起一行
    sorted_vals = np.sort(pc2)
    row_count = 1
    prev = sorted_vals[0]
    for v in sorted_vals[1:]:
        if v - prev > y_tol:
            row_count += 1
        prev = v

    return row_count


def count_rows_cluster_dbscan(df, eps=None):
    mask = (df["x_center"] >= 50) & (df["x_center"] <= 300)
    filtered_df = df.loc[mask]
    # 1. 做 PCA 找到正交于“行”的 PC2 轴
    coords = filtered_df[["x_center", "y_center"]].values

    pca = PCA(n_components=2).fit(coords)
    pc2 = pca.components_[1]  # PC2 单位向量，长度为 2

    # 2. 每个中心点在 PC2 轴上的投影距离
    proj_distances = coords.dot(pc2)
    filtered_df["proj_dist"] = proj_distances

    proj_coeff = abs(pc2[1])
    height_proj = filtered_df["height_px"] * proj_coeff
    filtered_df["height_proj"] = height_proj
    eps = height_proj.mean() * 3
    # 3. 在一维 PC2 上跑 DBSCAN
    clustering = DBSCAN(eps=eps, min_samples=2).fit(filtered_df[["y_center"]])
    labels = clustering.labels_
    # 不同 label 数即为行数
    return len(set(labels))


def compute_disorder(df):
    """
    以最近邻距的变异系数（CV = std / mean）衡量气孔排列“混乱程度”
    """
    pts = df[["x_center", "y_center"]].values
    D = distance_matrix(pts, pts)
    # 把自己到自己的距离设为大数以排除
    np.fill_diagonal(D, np.inf)
    nn_dist = D.min(axis=1)
    return nn_dist.std() / nn_dist.mean()


def compute_areas(df):
    """返回每个框的像素面积，以及总面积和平均面积"""
    df["area_px2"] = df["width_px"] * df["height_px"]
    return df["area_px2"].sum(), df["area_px2"].mean(), df["area_px2"]

# %%
image_path = "海南预测/81 (3)_det.jpg"  # 替换为你的图片路径
yolo_txt = "海南预测/81 (3).txt"  # 替换为你的检测结果 txt


# 1. 读取图像以获取尺寸
img = cv2.imread(image_path)
if img is None:
    raise FileNotFoundError(f"Cannot open image: {image_path}")
H, W = img.shape[:2]

# 2. 载入 YOLO 检测框
boxes = load_yolo_boxes(yolo_txt, img_w=W, img_h=H)
median_region_hits(boxes, W, region_width=20, n_trials=10)
# Out:
# 11.4

# %%
if __name__ == "__main__":
    # --- 用户设置部分 ---
    image_path = "海南预测/81 (3)_det.jpg"  # 替换为你的图片路径
    yolo_txt = "海南预测/81 (3).txt"  # 替换为你的检测结果 txt
    # ------------------------

    # 1. 读取图像以获取尺寸
    img = cv2.imread(image_path)
    if img is None:
        raise FileNotFoundError(f"Cannot open image: {image_path}")
    H, W = img.shape[:2]

    # 2. 载入 YOLO 检测框
    boxes = load_yolo_boxes(yolo_txt, img_w=W, img_h=H)

    # 3. 统计气孔数 & 密度
    n = len(boxes)
    density = compute_density(n, W, H)

    # 4. 行数
    n_rows = count_rows_cluster_dbscan(boxes)

    # 5. 混乱程度
    disorder_cv = compute_disorder(boxes)

    # 6. 面积统计
    total_area, mean_area, area_series = compute_areas(boxes)

    # 7. 输出结果
    print(f"气孔总数: {n}")
    print(f"气孔密度 (每像素): {density:.3e}")
    print(f"气孔行数: {n_rows}")
    print(f"气孔排列混乱程度 (CV of NN distances): {disorder_cv:.3f}")
    print(f"气孔总面积 (px²): {total_area:.1f}")
    print(f"气孔平均面积 (px²): {mean_area:.1f}")

    # 如需将每个气孔面积保存为 CSV，可取消下面注释：
    # area_series.to_csv('stomata_areas.csv', index=False)
# Out:
# 气孔总数: 320
# 气孔密度 (每像素): 1.665e-04
# 气孔行数: 10
# 气孔排列混乱程度 (CV of NN distances): 0.198
# 气孔总面积 (px²): 513933.0
# 气孔平均面积 (px²): 1606.0
# <positron-console-cell-205>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <positron-console-cell-205>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import os
import cv2
import numpy as np
import pandas as pd
from scipy.spatial import distance_matrix

# %%
# —— 前面那些函数保持不变 —— #
# load_yolo_boxes, compute_density, count_rows, compute_disorder, compute_areas
# 请确保这几个函数已经和之前一样定义在脚本中


def process_detect_folder(image_dir, output_csv="stomata_summary.csv"):
    records = []

    for fname in os.listdir(image_dir):
        if not fname.lower().endswith((".jpg", ".jpeg", ".png", ".tif", ".tiff")):
            continue

        image_path = os.path.join(image_dir, fname)
        # 构造同名 txt 路径：去掉扩展名，换成 .txt
        base, _ = os.path.splitext(fname)
        base = base.replace("_det", "")
        yolo_txt = os.path.join(image_dir, base + ".txt")

        if not os.path.exists(yolo_txt):
            print(f"警告：未找到检测结果 {yolo_txt}，跳过 {fname}")
            continue

        # 1. 读取图像
        img = cv2.imread(image_path)
        if img is None:
            print(f"警告：无法读取 {fname}")
            continue
        H, W = img.shape[:2]

        # 2. 载入检测框
        boxes = load_yolo_boxes(yolo_txt, img_w=W, img_h=H)

        # 3–6 计算指标
        n = len(boxes)
        density = compute_density(n, W, H)
        n_rows = median_region_hits(boxes, W, region_width=30, n_trials=200)
        disorder = compute_disorder(boxes)
        total_a, mean_a, _ = compute_areas(boxes)

        # 记录
        records.append(
            {
                "image": fname,
                "n_stomata": n,
                "density_per_px": density,
                "n_rows": n_rows,
                "disorder_cv": disorder,
                "total_area_px2": total_a,
                "mean_area_px2": mean_a,
            }
        )

        print(
            f"[{fname}] 气孔: {n}, 密度: {density:.3e}, 行数: {n_rows}, 混乱度(CV): {disorder:.3f}"
        )

    # 汇总保存
    df = pd.DataFrame(records)
    df.to_csv(output_csv, index=False)
    print(f"\n已处理 {len(df)} 张图片，结果保存到 {output_csv}")

# %%
if __name__ == "__main__":
    IMAGE_FOLDER = "海南预测"  # 替换为你的图片+txt文件夹
    process_detect_folder(IMAGE_FOLDER, output_csv="海南叶片气孔统计.csv")
    IMAGE_FOLDER = "河南预测"  # 替换为你的图片+txt文件夹
    process_detect_folder(IMAGE_FOLDER, output_csv="河南叶片气孔统计.csv")
# Out:
# [121 (2)_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 10.97, 混乱度(CV): 0.310
# [121 (3)_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.7, 混乱度(CV): 0.226
# [121_det.jpg] 气孔: 219, 密度: 1.139e-04, 行数: 8.985, 混乱度(CV): 0.281
# [122 (2)_det.jpg] 气孔: 275, 密度: 1.431e-04, 行数: 11.68, 混乱度(CV): 0.278
# [122 (3)_det.jpg] 气孔: 295, 密度: 1.535e-04, 行数: 12.745, 混乱度(CV): 0.249
# [122 (4)_det.jpg] 气孔: 303, 密度: 1.577e-04, 行数: 13.005, 混乱度(CV): 0.252
# [122_det.jpg] 气孔: 295, 密度: 1.535e-04, 行数: 12.775, 混乱度(CV): 0.260
# [123 (2)_det.jpg] 气孔: 290, 密度: 1.507e-04, 行数: 11.44, 混乱度(CV): 0.210
# [123 (3)_det.jpg] 气孔: 232, 密度: 1.207e-04, 行数: 10.255, 混乱度(CV): 0.261
# [123_det.jpg] 气孔: 214, 密度: 1.112e-04, 行数: 9.235, 混乱度(CV): 0.283
# [124 (2)_det.jpg] 气孔: 161, 密度: 8.369e-05, 行数: 7.215, 混乱度(CV): 0.250
# [124 (3)_det.jpg] 气孔: 189, 密度: 9.839e-05, 行数: 8.26, 混乱度(CV): 0.239
# [124_det.jpg] 气孔: 177, 密度: 9.210e-05, 行数: 7.455, 混乱度(CV): 0.211
# [126 (2)_det.jpg] 气孔: 189, 密度: 9.824e-05, 行数: 8.305, 混乱度(CV): 0.291
# [126 (3)_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.335, 混乱度(CV): 0.187
# [126 (4)_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 8.905, 混乱度(CV): 0.154
# [126_det.jpg] 气孔: 175, 密度: 9.105e-05, 行数: 7.655, 混乱度(CV): 0.228
# [128 (2)_det.jpg] 气孔: 171, 密度: 8.897e-05, 行数: 8.075, 混乱度(CV): 0.347
# [128 (3)_det.jpg] 气孔: 201, 密度: 1.046e-04, 行数: 8.985, 混乱度(CV): 0.283
# [128_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 9.24, 混乱度(CV): 0.303
# [130 (2)_det.jpg] 气孔: 266, 密度: 1.384e-04, 行数: 10.45, 混乱度(CV): 0.250
# [130 (3)_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 8.945, 混乱度(CV): 0.190
# [130_det.jpg] 气孔: 198, 密度: 1.029e-04, 行数: 8.44, 混乱度(CV): 0.191
# [131 (2)_det.jpg] 气孔: 200, 密度: 1.041e-04, 行数: 8.395, 混乱度(CV): 0.169
# [131 (3)_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.425, 混乱度(CV): 0.256
# [131_det.jpg] 气孔: 211, 密度: 1.098e-04, 行数: 9.035, 混乱度(CV): 0.217
# [132 (2)_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.705, 混乱度(CV): 0.174
# [132 (3)_det.jpg] 气孔: 260, 密度: 1.353e-04, 行数: 10.04, 混乱度(CV): 0.174
# [132_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 9.805, 混乱度(CV): 0.189
# [133 (2)_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 9.145, 混乱度(CV): 0.228
# [133 (3)_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.34, 混乱度(CV): 0.205
# [133_det.jpg] 气孔: 178, 密度: 9.253e-05, 行数: 8.345, 混乱度(CV): 0.257
# [134 (2)_det.jpg] 气孔: 220, 密度: 1.144e-04, 行数: 9.075, 混乱度(CV): 0.269
# [134 (3)_det.jpg] 气孔: 187, 密度: 9.730e-05, 行数: 8.355, 混乱度(CV): 0.262
# [134_det.jpg] 气孔: 147, 密度: 7.649e-05, 行数: 6.45, 混乱度(CV): 0.228
# [135 (2)_det.jpg] 气孔: 206, 密度: 1.072e-04, 行数: 9.835, 混乱度(CV): 0.276
# [135 (3)_det.jpg] 气孔: 203, 密度: 1.056e-04, 行数: 9.52, 混乱度(CV): 0.297
# [135_det.jpg] 气孔: 226, 密度: 1.176e-04, 行数: 10.31, 混乱度(CV): 0.308
# [136 (2)_det.jpg] 气孔: 279, 密度: 1.452e-04, 行数: 11.645, 混乱度(CV): 0.291
# [136 (3)_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 10.41, 混乱度(CV): 0.234
# [136 (4)_det.jpg] 气孔: 204, 密度: 1.060e-04, 行数: 9.265, 混乱度(CV): 0.254
# [136_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 9.05, 混乱度(CV): 0.265
# [137 (2)_det.jpg] 气孔: 259, 密度: 1.346e-04, 行数: 10.465, 混乱度(CV): 0.188
# [137 (3)_det.jpg] 气孔: 279, 密度: 1.452e-04, 行数: 11.08, 混乱度(CV): 0.256
# [137_det.jpg] 气孔: 258, 密度: 1.342e-04, 行数: 10.675, 混乱度(CV): 0.223
# [138 (2)_det.jpg] 气孔: 226, 密度: 1.175e-04, 行数: 8.89, 混乱度(CV): 0.203
# [138 (3)_det.jpg] 气孔: 222, 密度: 1.155e-04, 行数: 9.075, 混乱度(CV): 0.243
# [138_det.jpg] 气孔: 206, 密度: 1.071e-04, 行数: 8.375, 混乱度(CV): 0.166
# [139 (2)_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.35, 混乱度(CV): 0.269
# [139 (3)_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 10.685, 混乱度(CV): 0.283
# [139_det.jpg] 气孔: 222, 密度: 1.154e-04, 行数: 8.86, 混乱度(CV): 0.312
# [140 (2)_det.jpg] 气孔: 211, 密度: 1.098e-04, 行数: 9.415, 混乱度(CV): 0.208
# [140 (3)_det.jpg] 气孔: 230, 密度: 1.197e-04, 行数: 9.895, 混乱度(CV): 0.179
# [140 (4)_det.jpg] 气孔: 266, 密度: 1.384e-04, 行数: 10.68, 混乱度(CV): 0.237
# [140_det.jpg] 气孔: 202, 密度: 1.050e-04, 行数: 8.775, 混乱度(CV): 0.181
# [141 (2)_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 8.9, 混乱度(CV): 0.222
# [141 (3)_det.jpg] 气孔: 228, 密度: 1.186e-04, 行数: 9.6, 混乱度(CV): 0.219
# [141 (4)_det.jpg] 气孔: 219, 密度: 1.139e-04, 行数: 8.595, 混乱度(CV): 0.240
# [141_det.jpg] 气孔: 217, 密度: 1.129e-04, 行数: 8.49, 混乱度(CV): 0.174
# [142 (2)_det.jpg] 气孔: 199, 密度: 1.035e-04, 行数: 8.365, 混乱度(CV): 0.256
# [142 (3)_det.jpg] 气孔: 209, 密度: 1.086e-04, 行数: 8.865, 混乱度(CV): 0.230
# [142 (4)_det.jpg] 气孔: 185, 密度: 9.626e-05, 行数: 7.87, 混乱度(CV): 0.210
# [142_det.jpg] 气孔: 166, 密度: 8.637e-05, 行数: 7.905, 混乱度(CV): 0.200
# [143 (2)_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 9.5, 混乱度(CV): 0.248
# [143 (3)_det.jpg] 气孔: 217, 密度: 1.129e-04, 行数: 9.555, 混乱度(CV): 0.285
# [143_det.jpg] 气孔: 217, 密度: 1.129e-04, 行数: 9.825, 混乱度(CV): 0.262
# [144 (2)_det.jpg] 气孔: 219, 密度: 1.139e-04, 行数: 9.89, 混乱度(CV): 0.219
# [144 (3)_det.jpg] 气孔: 239, 密度: 1.242e-04, 行数: 10.33, 混乱度(CV): 0.338
# [144_det.jpg] 气孔: 219, 密度: 1.139e-04, 行数: 9.87, 混乱度(CV): 0.290
# [145 (2)_det.jpg] 气孔: 170, 密度: 8.845e-05, 行数: 7.66, 混乱度(CV): 0.298
# [145 (3)_det.jpg] 气孔: 211, 密度: 1.097e-04, 行数: 8.165, 混乱度(CV): 0.230
# [145_det.jpg] 气孔: 229, 密度: 1.192e-04, 行数: 9.875, 混乱度(CV): 0.197
# [146 (2)_det.jpg] 气孔: 194, 密度: 1.009e-04, 行数: 8.02, 混乱度(CV): 0.263
# [146 (3)_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 9.36, 混乱度(CV): 0.208
# [146_det.jpg] 气孔: 235, 密度: 1.223e-04, 行数: 9.48, 混乱度(CV): 0.243
# [147 (2)_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.375, 混乱度(CV): 0.280
# [147 (3)_det.jpg] 气孔: 270, 密度: 1.405e-04, 行数: 10.75, 混乱度(CV): 0.233
# [147_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 9.815, 混乱度(CV): 0.340
# [149 (2)_det.jpg] 气孔: 319, 密度: 1.660e-04, 行数: 12.415, 混乱度(CV): 0.189
# [149 (3)_det.jpg] 气孔: 272, 密度: 1.415e-04, 行数: 10.89, 混乱度(CV): 0.243
# [149_det.jpg] 气孔: 271, 密度: 1.410e-04, 行数: 11.265, 混乱度(CV): 0.193
# [150 (2)_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 9.045, 混乱度(CV): 0.322
# [150 (3)_det.jpg] 气孔: 238, 密度: 1.237e-04, 行数: 10.06, 混乱度(CV): 0.287
# [150_det.jpg] 气孔: 168, 密度: 8.741e-05, 行数: 7.635, 混乱度(CV): 0.283
# [151 (2)_det.jpg] 气孔: 283, 密度: 1.471e-04, 行数: 11.84, 混乱度(CV): 0.274
# [151 (3)_det.jpg] 气孔: 331, 密度: 1.722e-04, 行数: 13.37, 混乱度(CV): 0.198
# [151_det.jpg] 气孔: 336, 密度: 1.748e-04, 行数: 13.27, 混乱度(CV): 0.220
# [152 (2)_det.jpg] 气孔: 303, 密度: 1.577e-04, 行数: 11.495, 混乱度(CV): 0.202
# [152 (3)_det.jpg] 气孔: 295, 密度: 1.533e-04, 行数: 11.53, 混乱度(CV): 0.221
# [152_det.jpg] 气孔: 191, 密度: 9.928e-05, 行数: 9.05, 混乱度(CV): 0.232
# [153 (2)_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 10.305, 混乱度(CV): 0.239
# [153_det.jpg] 气孔: 261, 密度: 1.357e-04, 行数: 10.655, 混乱度(CV): 0.224
# [154 (2)_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 8.915, 混乱度(CV): 0.239
# [154 (3)_det.jpg] 气孔: 200, 密度: 1.041e-04, 行数: 8.95, 混乱度(CV): 0.269
# [154_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.99, 混乱度(CV): 0.278
# [155 (2)_det.jpg] 气孔: 214, 密度: 1.113e-04, 行数: 8.875, 混乱度(CV): 0.212
# [155 (3)_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.305, 混乱度(CV): 0.221
# [155_det.jpg] 气孔: 274, 密度: 1.426e-04, 行数: 11.085, 混乱度(CV): 0.206
# [156 (2)_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.76, 混乱度(CV): 0.196
# [156 (3)_det.jpg] 气孔: 225, 密度: 1.170e-04, 行数: 9.055, 混乱度(CV): 0.205
# [156 (4)_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 8.44, 混乱度(CV): 0.187
# [156_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 10.0, 混乱度(CV): 0.180
# [157 (2)_det.jpg] 气孔: 304, 密度: 1.580e-04, 行数: 12.24, 混乱度(CV): 0.321
# [157 (3)_det.jpg] 气孔: 250, 密度: 1.301e-04, 行数: 10.13, 混乱度(CV): 0.333
# [157_det.jpg] 气孔: 281, 密度: 1.462e-04, 行数: 11.03, 混乱度(CV): 0.283
# [159 (2)_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 9.745, 混乱度(CV): 0.241
# [159 (3)_det.jpg] 气孔: 280, 密度: 1.457e-04, 行数: 11.01, 混乱度(CV): 0.239
# [159_det.jpg] 气孔: 267, 密度: 1.389e-04, 行数: 11.025, 混乱度(CV): 0.224
# [160 (2)_det.jpg] 气孔: 221, 密度: 1.150e-04, 行数: 9.305, 混乱度(CV): 0.260
# [160 (3)_det.jpg] 气孔: 244, 密度: 1.270e-04, 行数: 9.5, 混乱度(CV): 0.270
# [160 (4)_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.72, 混乱度(CV): 0.231
# [160_det.jpg] 气孔: 206, 密度: 1.072e-04, 行数: 8.47, 混乱度(CV): 0.211
# [161 (2)_det.jpg] 气孔: 226, 密度: 1.176e-04, 行数: 9.64, 混乱度(CV): 0.236
# [161 (3)_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.9, 混乱度(CV): 0.266
# [161_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 9.3, 混乱度(CV): 0.202
# [162 (2)_det.jpg] 气孔: 276, 密度: 1.436e-04, 行数: 11.565, 混乱度(CV): 0.277
# [162 (3)_det.jpg] 气孔: 279, 密度: 1.452e-04, 行数: 11.51, 混乱度(CV): 0.292
# [162_det.jpg] 气孔: 275, 密度: 1.431e-04, 行数: 11.31, 混乱度(CV): 0.228
# [163 (2)_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 8.69, 混乱度(CV): 0.336
# [163 (3)_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 10.275, 混乱度(CV): 0.283
# [163 (4)_det.jpg] 气孔: 228, 密度: 1.186e-04, 行数: 9.365, 混乱度(CV): 0.246
# [163_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 8.945, 混乱度(CV): 0.236
# [164 (2)_det.jpg] 气孔: 270, 密度: 1.405e-04, 行数: 11.315, 混乱度(CV): 0.206
# [164 (3)_det.jpg] 气孔: 210, 密度: 1.092e-04, 行数: 9.335, 混乱度(CV): 0.213
# [164 (4)_det.jpg] 气孔: 203, 密度: 1.055e-04, 行数: 8.855, 混乱度(CV): 0.227
# [164_det.jpg] 气孔: 244, 密度: 1.270e-04, 行数: 10.735, 混乱度(CV): 0.256
# [166 (2)_det.jpg] 气孔: 305, 密度: 1.587e-04, 行数: 11.845, 混乱度(CV): 0.261
# [166 (3)_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 9.61, 混乱度(CV): 0.169
# [166 (4)_det.jpg] 气孔: 274, 密度: 1.426e-04, 行数: 10.975, 混乱度(CV): 0.222
# [166_det.jpg] 气孔: 230, 密度: 1.197e-04, 行数: 10.03, 混乱度(CV): 0.265
# [167 (2)_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.8, 混乱度(CV): 0.229
# [167 (3)_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.395, 混乱度(CV): 0.264
# [167_det.jpg] 气孔: 270, 密度: 1.403e-04, 行数: 10.69, 混乱度(CV): 0.245
# [168 (2)_det.jpg] 气孔: 223, 密度: 1.159e-04, 行数: 9.0, 混乱度(CV): 0.167
# [168 (3)_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.115, 混乱度(CV): 0.251
# [168_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.79, 混乱度(CV): 0.192
# [169 (2)_det.jpg] 气孔: 274, 密度: 1.426e-04, 行数: 10.965, 混乱度(CV): 0.342
# [169 (3)_det.jpg] 气孔: 282, 密度: 1.466e-04, 行数: 11.065, 混乱度(CV): 0.367
# [169 (4)_det.jpg] 气孔: 244, 密度: 1.270e-04, 行数: 10.135, 混乱度(CV): 0.352
# [169 (5)_det.jpg] 气孔: 328, 密度: 1.707e-04, 行数: 13.41, 混乱度(CV): 0.306
# [169_det.jpg] 气孔: 329, 密度: 1.712e-04, 行数: 13.075, 混乱度(CV): 0.322
# [170 (2)_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 8.4, 混乱度(CV): 0.253
# [170 (3)_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 10.785, 混乱度(CV): 0.270
# [170_det.jpg] 气孔: 198, 密度: 1.030e-04, 行数: 9.33, 混乱度(CV): 0.273
# [171 (2)_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 9.16, 混乱度(CV): 0.145
# [171 (3)_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.955, 混乱度(CV): 0.219
# [171 (4)_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 9.4, 混乱度(CV): 0.178
# [171_det.jpg] 气孔: 250, 密度: 1.300e-04, 行数: 10.61, 混乱度(CV): 0.160
# [172 (2)_det.jpg] 气孔: 236, 密度: 1.228e-04, 行数: 9.905, 混乱度(CV): 0.259
# [172 (3)_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.66, 混乱度(CV): 0.244
# [172 (4)_det.jpg] 气孔: 241, 密度: 1.255e-04, 行数: 9.575, 混乱度(CV): 0.210
# [172_det.jpg] 气孔: 232, 密度: 1.207e-04, 行数: 9.7, 混乱度(CV): 0.265
# [173 (2)_det.jpg] 气孔: 228, 密度: 1.186e-04, 行数: 9.575, 混乱度(CV): 0.258
# [173 (3)_det.jpg] 气孔: 305, 密度: 1.587e-04, 行数: 13.015, 混乱度(CV): 0.229
# [173_det.jpg] 气孔: 239, 密度: 1.242e-04, 行数: 10.76, 混乱度(CV): 0.290
# [174 (2)_det.jpg] 气孔: 237, 密度: 1.233e-04, 行数: 9.685, 混乱度(CV): 0.171
# [174 (3)_det.jpg] 气孔: 257, 密度: 1.336e-04, 行数: 10.53, 混乱度(CV): 0.273
# [174_det.jpg] 气孔: 235, 密度: 1.223e-04, 行数: 9.605, 混乱度(CV): 0.247
# [175 (2)_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.32, 混乱度(CV): 0.198
# [175 (3)_det.jpg] 气孔: 222, 密度: 1.154e-04, 行数: 9.33, 混乱度(CV): 0.206
# [175 (4)_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 9.12, 混乱度(CV): 0.212
# [175_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 9.655, 混乱度(CV): 0.236
# [176 (2)_det.jpg] 气孔: 207, 密度: 1.076e-04, 行数: 8.965, 混乱度(CV): 0.309
# [176 (3)_det.jpg] 气孔: 264, 密度: 1.374e-04, 行数: 10.92, 混乱度(CV): 0.226
# [176_det.jpg] 气孔: 227, 密度: 1.180e-04, 行数: 9.455, 混乱度(CV): 0.248
# [177 (2)_det.jpg] 气孔: 238, 密度: 1.237e-04, 行数: 10.15, 混乱度(CV): 0.238
# [177 (3)_det.jpg] 气孔: 285, 密度: 1.483e-04, 行数: 11.375, 混乱度(CV): 0.272
# [177_det.jpg] 气孔: 342, 密度: 1.778e-04, 行数: 13.94, 混乱度(CV): 0.260
# [179 (2)_det.jpg] 气孔: 199, 密度: 1.034e-04, 行数: 8.41, 混乱度(CV): 0.175
# [179 (3)_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 9.665, 混乱度(CV): 0.211
# [179_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 9.01, 混乱度(CV): 0.247
# [180 (2)_det.jpg] 气孔: 236, 密度: 1.228e-04, 行数: 9.64, 混乱度(CV): 0.202
# [180 (3)_det.jpg] 气孔: 262, 密度: 1.363e-04, 行数: 10.75, 混乱度(CV): 0.238
# [180 (4)_det.jpg] 气孔: 202, 密度: 1.050e-04, 行数: 9.095, 混乱度(CV): 0.193
# [180_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 10.095, 混乱度(CV): 0.176
# [181 (2)_det.jpg] 气孔: 258, 密度: 1.342e-04, 行数: 11.045, 混乱度(CV): 0.219
# [181 (3)_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.915, 混乱度(CV): 0.181
# [181_det.jpg] 气孔: 198, 密度: 1.029e-04, 行数: 8.28, 混乱度(CV): 0.212
# [182 (2)_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.495, 混乱度(CV): 0.254
# [182 (3)_det.jpg] 气孔: 258, 密度: 1.342e-04, 行数: 10.46, 混乱度(CV): 0.268
# [182_det.jpg] 气孔: 238, 密度: 1.237e-04, 行数: 9.445, 混乱度(CV): 0.258
# [183 (2)_det.jpg] 气孔: 277, 密度: 1.441e-04, 行数: 11.205, 混乱度(CV): 0.212
# [183 (3)_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 9.445, 混乱度(CV): 0.263
# [183_det.jpg] 气孔: 190, 密度: 9.886e-05, 行数: 8.105, 混乱度(CV): 0.238
# [184 (2)_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 10.605, 混乱度(CV): 0.270
# [184 (3)_det.jpg] 气孔: 282, 密度: 1.467e-04, 行数: 11.6, 混乱度(CV): 0.281
# [184_det.jpg] 气孔: 246, 密度: 1.280e-04, 行数: 10.005, 混乱度(CV): 0.250
# [185 (2)_det.jpg] 气孔: 185, 密度: 9.617e-05, 行数: 7.675, 混乱度(CV): 0.292
# [185 (3)_det.jpg] 气孔: 196, 密度: 1.019e-04, 行数: 8.25, 混乱度(CV): 0.314
# [185 (4)_det.jpg] 气孔: 197, 密度: 1.024e-04, 行数: 8.225, 混乱度(CV): 0.274
# [185_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 9.805, 混乱度(CV): 0.239
# [186 (2)_det.jpg] 气孔: 131, 密度: 6.816e-05, 行数: 6.115, 混乱度(CV): 0.231
# [186 (3)_det.jpg] 气孔: 276, 密度: 1.436e-04, 行数: 10.935, 混乱度(CV): 0.268
# [186_det.jpg] 气孔: 159, 密度: 8.273e-05, 行数: 6.87, 混乱度(CV): 0.209
# [187 (2)_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 8.84, 混乱度(CV): 0.225
# [187 (3)_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 8.49, 混乱度(CV): 0.213
# [187_det.jpg] 气孔: 186, 密度: 9.669e-05, 行数: 8.21, 混乱度(CV): 0.234
# [188 (2)_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 10.19, 混乱度(CV): 0.178
# [188 (3)_det.jpg] 气孔: 189, 密度: 9.834e-05, 行数: 7.965, 混乱度(CV): 0.192
# [188_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 8.085, 混乱度(CV): 0.192
# [189 (2)_det.jpg] 气孔: 164, 密度: 8.533e-05, 行数: 7.42, 混乱度(CV): 0.232
# [189 (3)_det.jpg] 气孔: 207, 密度: 1.077e-04, 行数: 8.345, 混乱度(CV): 0.256
# [189_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 8.895, 混乱度(CV): 0.232
# [190 (2)_det.jpg] 气孔: 186, 密度: 9.678e-05, 行数: 7.77, 混乱度(CV): 0.235
# [190 (3)_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 10.475, 混乱度(CV): 0.237
# [190_det.jpg] 气孔: 208, 密度: 1.081e-04, 行数: 8.745, 混乱度(CV): 0.187
# [191 (2)_det.jpg] 气孔: 225, 密度: 1.170e-04, 行数: 9.365, 混乱度(CV): 0.278
# [191 (3)_det.jpg] 气孔: 226, 密度: 1.176e-04, 行数: 9.04, 混乱度(CV): 0.280
# [191_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 9.525, 混乱度(CV): 0.240
# [192 (2)_det.jpg] 气孔: 227, 密度: 1.181e-04, 行数: 9.405, 混乱度(CV): 0.308
# [192 (3)_det.jpg] 气孔: 196, 密度: 1.019e-04, 行数: 8.88, 混乱度(CV): 0.326
# [192_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 9.76, 混乱度(CV): 0.273
# [194 (2)_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 11.1, 混乱度(CV): 0.273
# [194 (3)_det.jpg] 气孔: 236, 密度: 1.228e-04, 行数: 9.815, 混乱度(CV): 0.257
# [194_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 9.925, 混乱度(CV): 0.281
# [195 (2)_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 10.46, 混乱度(CV): 0.255
# [195 (3)_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.395, 混乱度(CV): 0.234
# [195_det.jpg] 气孔: 224, 密度: 1.164e-04, 行数: 9.3, 混乱度(CV): 0.266
# [196 (2)_det.jpg] 气孔: 220, 密度: 1.144e-04, 行数: 9.31, 混乱度(CV): 0.259
# [196 (3)_det.jpg] 气孔: 209, 密度: 1.087e-04, 行数: 9.36, 混乱度(CV): 0.184
# [196_det.jpg] 气孔: 180, 密度: 9.357e-05, 行数: 8.435, 混乱度(CV): 0.219
# [197 (2)_det.jpg] 气孔: 273, 密度: 1.420e-04, 行数: 11.565, 混乱度(CV): 0.245
# [197 (3)_det.jpg] 气孔: 330, 密度: 1.715e-04, 行数: 12.19, 混乱度(CV): 0.218
# [197 (4)_det.jpg] 气孔: 342, 密度: 1.779e-04, 行数: 14.375, 混乱度(CV): 0.233
# [197_det.jpg] 气孔: 280, 密度: 1.457e-04, 行数: 11.345, 混乱度(CV): 0.244
# [198 (2)_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 9.525, 混乱度(CV): 0.304
# [198 (3)_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 9.695, 混乱度(CV): 0.247
# [198_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 9.975, 混乱度(CV): 0.270
# [199 (2)_det.jpg] 气孔: 263, 密度: 1.368e-04, 行数: 10.5, 混乱度(CV): 0.235
# [199 (3)_det.jpg] 气孔: 295, 密度: 1.533e-04, 行数: 11.735, 混乱度(CV): 0.221
# [199_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 10.81, 混乱度(CV): 0.211
# [200 (2)_det.jpg] 气孔: 240, 密度: 1.248e-04, 行数: 9.365, 混乱度(CV): 0.207
# [200 (3)_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 10.445, 混乱度(CV): 0.196
# [200_det.jpg] 气孔: 188, 密度: 9.782e-05, 行数: 7.775, 混乱度(CV): 0.174
# [201 (2)_det.jpg] 气孔: 179, 密度: 9.314e-05, 行数: 7.425, 混乱度(CV): 0.220
# [201 (3)_det.jpg] 气孔: 164, 密度: 8.525e-05, 行数: 6.94, 混乱度(CV): 0.164
# [201_det.jpg] 气孔: 242, 密度: 1.258e-04, 行数: 9.635, 混乱度(CV): 0.204
# [202 (2)_det.jpg] 气孔: 159, 密度: 8.273e-05, 行数: 7.76, 混乱度(CV): 0.231
# [202 (3)_det.jpg] 气孔: 263, 密度: 1.368e-04, 行数: 10.86, 混乱度(CV): 0.199
# [202_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 9.24, 混乱度(CV): 0.184
# [203 (2)_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 8.85, 混乱度(CV): 0.217
# [203 (3)_det.jpg] 气孔: 202, 密度: 1.050e-04, 行数: 8.455, 混乱度(CV): 0.193
# [203_det.jpg] 气孔: 218, 密度: 1.133e-04, 行数: 9.19, 混乱度(CV): 0.210
# [204 (2)_det.jpg] 气孔: 193, 密度: 1.003e-04, 行数: 8.03, 混乱度(CV): 0.217
# [204 (3)_det.jpg] 气孔: 229, 密度: 1.192e-04, 行数: 9.415, 混乱度(CV): 0.181
# [204_det.jpg] 气孔: 241, 密度: 1.253e-04, 行数: 9.06, 混乱度(CV): 0.200
# [205 (2)_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 8.97, 混乱度(CV): 0.249
# [205 (3)_det.jpg] 气孔: 317, 密度: 1.648e-04, 行数: 13.28, 混乱度(CV): 0.324
# [205_det.jpg] 气孔: 213, 密度: 1.108e-04, 行数: 9.455, 混乱度(CV): 0.290
# [206 (2)_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 9.21, 混乱度(CV): 0.268
# [206 (3)_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.675, 混乱度(CV): 0.210
# [206_det.jpg] 气孔: 226, 密度: 1.176e-04, 行数: 9.105, 混乱度(CV): 0.171
# [207 (2)_det.jpg] 气孔: 279, 密度: 1.450e-04, 行数: 10.925, 混乱度(CV): 0.207
# [207 (3)_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 10.55, 混乱度(CV): 0.274
# [207_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 10.265, 混乱度(CV): 0.285
# [208 (2)_det.jpg] 气孔: 175, 密度: 9.097e-05, 行数: 7.8, 混乱度(CV): 0.170
# [208 (3)_det.jpg] 气孔: 174, 密度: 9.045e-05, 行数: 7.785, 混乱度(CV): 0.176
# [208 (4)_det.jpg] 气孔: 199, 密度: 1.035e-04, 行数: 8.945, 混乱度(CV): 0.226
# [208_det.jpg] 气孔: 172, 密度: 8.949e-05, 行数: 7.365, 混乱度(CV): 0.222
# [209 (2)_det.jpg] 气孔: 184, 密度: 9.574e-05, 行数: 7.885, 混乱度(CV): 0.251
# [209 (3)_det.jpg] 气孔: 258, 密度: 1.342e-04, 行数: 10.6, 混乱度(CV): 0.317
# [209_det.jpg] 气孔: 178, 密度: 9.262e-05, 行数: 7.955, 混乱度(CV): 0.274
# [212 (2)_det.jpg] 气孔: 326, 密度: 1.696e-04, 行数: 13.05, 混乱度(CV): 0.278
# [212 (3)_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 10.125, 混乱度(CV): 0.225
# [212_det.jpg] 气孔: 294, 密度: 1.530e-04, 行数: 12.0, 混乱度(CV): 0.251
# [213 (2)_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 9.34, 混乱度(CV): 0.267
# [213 (3)_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 11.125, 混乱度(CV): 0.261
# [213 (4)_det.jpg] 气孔: 254, 密度: 1.322e-04, 行数: 10.735, 混乱度(CV): 0.236
# [213_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 9.59, 混乱度(CV): 0.282
# [215 (2)_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 11.45, 混乱度(CV): 0.266
# [215 (3)_det.jpg] 气孔: 209, 密度: 1.087e-04, 行数: 9.135, 混乱度(CV): 0.243
# [215_det.jpg] 气孔: 273, 密度: 1.420e-04, 行数: 11.13, 混乱度(CV): 0.233
# [216 (2)_det.jpg] 气孔: 224, 密度: 1.164e-04, 行数: 10.035, 混乱度(CV): 0.258
# [216 (3)_det.jpg] 气孔: 266, 密度: 1.384e-04, 行数: 11.35, 混乱度(CV): 0.164
# [216_det.jpg] 气孔: 187, 密度: 9.730e-05, 行数: 8.29, 混乱度(CV): 0.205
# [217 (2)_det.jpg] 气孔: 230, 密度: 1.197e-04, 行数: 9.86, 混乱度(CV): 0.238
# [217 (3)_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 10.95, 混乱度(CV): 0.241
# [217_det.jpg] 气孔: 233, 密度: 1.211e-04, 行数: 10.495, 混乱度(CV): 0.256
# [218 (2)_det.jpg] 气孔: 301, 密度: 1.565e-04, 行数: 11.07, 混乱度(CV): 0.252
# [218 (3)_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 8.81, 混乱度(CV): 0.316
# [218_det.jpg] 气孔: 246, 密度: 1.280e-04, 行数: 9.735, 混乱度(CV): 0.267
# [220 (2)_det.jpg] 气孔: 188, 密度: 9.772e-05, 行数: 8.105, 混乱度(CV): 0.194
# [220 (3)_det.jpg] 气孔: 211, 密度: 1.098e-04, 行数: 9.1, 混乱度(CV): 0.242
# [220_det.jpg] 气孔: 169, 密度: 8.793e-05, 行数: 7.755, 混乱度(CV): 0.247
# [221 (2)_det.jpg] 气孔: 323, 密度: 1.679e-04, 行数: 12.405, 混乱度(CV): 0.184
# [221 (3)_det.jpg] 气孔: 263, 密度: 1.368e-04, 行数: 11.095, 混乱度(CV): 0.231
# [221_det.jpg] 气孔: 229, 密度: 1.192e-04, 行数: 9.715, 混乱度(CV): 0.254
# [222 (2)_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 10.43, 混乱度(CV): 0.315
# [222 (3)_det.jpg] 气孔: 267, 密度: 1.389e-04, 行数: 11.165, 混乱度(CV): 0.287
# [222_det.jpg] 气孔: 270, 密度: 1.405e-04, 行数: 11.22, 混乱度(CV): 0.294
# [223 (2)_det.jpg] 气孔: 156, 密度: 8.117e-05, 行数: 7.02, 混乱度(CV): 0.258
# [223 (3)_det.jpg] 气孔: 149, 密度: 7.753e-05, 行数: 6.745, 混乱度(CV): 0.225
# [223_det.jpg] 气孔: 166, 密度: 8.629e-05, 行数: 7.47, 混乱度(CV): 0.234
# [224 (2)_det.jpg] 气孔: 177, 密度: 9.210e-05, 行数: 7.29, 混乱度(CV): 0.223
# [224 (3)_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 8.645, 混乱度(CV): 0.214
# [224_det.jpg] 气孔: 180, 密度: 9.366e-05, 行数: 7.905, 混乱度(CV): 0.161
# [225 (2)_det.jpg] 气孔: 196, 密度: 1.020e-04, 行数: 8.475, 混乱度(CV): 0.316
# [225 (3)_det.jpg] 气孔: 236, 密度: 1.228e-04, 行数: 9.33, 混乱度(CV): 0.223
# [225_det.jpg] 气孔: 211, 密度: 1.097e-04, 行数: 8.945, 混乱度(CV): 0.239
# [226 (2)_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 9.48, 混乱度(CV): 0.197
# [226 (3)_det.jpg] 气孔: 272, 密度: 1.415e-04, 行数: 10.63, 混乱度(CV): 0.244
# [226_det.jpg] 气孔: 214, 密度: 1.113e-04, 行数: 9.11, 混乱度(CV): 0.279
# [227 (2)_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 7.8, 混乱度(CV): 0.181
# [227 (3)_det.jpg] 气孔: 203, 密度: 1.056e-04, 行数: 8.645, 混乱度(CV): 0.213
# [227_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 7.875, 混乱度(CV): 0.212
# [228 (2)_det.jpg] 气孔: 242, 密度: 1.258e-04, 行数: 10.575, 混乱度(CV): 0.242
# [228 (3)_det.jpg] 气孔: 252, 密度: 1.310e-04, 行数: 10.375, 混乱度(CV): 0.299
# [228_det.jpg] 气孔: 259, 密度: 1.346e-04, 行数: 10.55, 混乱度(CV): 0.269
# [229 (2)_det.jpg] 气孔: 213, 密度: 1.108e-04, 行数: 8.515, 混乱度(CV): 0.202
# [229 (3)_det.jpg] 气孔: 161, 密度: 8.377e-05, 行数: 7.03, 混乱度(CV): 0.275
# [229_det.jpg] 气孔: 186, 密度: 9.678e-05, 行数: 7.705, 混乱度(CV): 0.206
# [230 (2)_det.jpg] 气孔: 177, 密度: 9.210e-05, 行数: 7.445, 混乱度(CV): 0.300
# [230 (3)_det.jpg] 气孔: 143, 密度: 7.440e-05, 行数: 6.415, 混乱度(CV): 0.307
# [230 (4)_det.jpg] 气孔: 200, 密度: 1.041e-04, 行数: 8.27, 混乱度(CV): 0.317
# [230_det.jpg] 气孔: 169, 密度: 8.785e-05, 行数: 7.62, 混乱度(CV): 0.291
# [231 (2)_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 9.435, 混乱度(CV): 0.247
# [231 (3)_det.jpg] 气孔: 314, 密度: 1.634e-04, 行数: 12.88, 混乱度(CV): 0.317
# [231_det.jpg] 气孔: 286, 密度: 1.487e-04, 行数: 11.02, 混乱度(CV): 0.320
# [233 (2)_det.jpg] 气孔: 201, 密度: 1.046e-04, 行数: 8.555, 混乱度(CV): 0.298
# [233 (3)_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.5, 混乱度(CV): 0.178
# [233_det.jpg] 气孔: 222, 密度: 1.155e-04, 行数: 9.255, 混乱度(CV): 0.246
# [234 (2)_det.jpg] 气孔: 277, 密度: 1.440e-04, 行数: 11.04, 混乱度(CV): 0.261
# [234 (3)_det.jpg] 气孔: 187, 密度: 9.730e-05, 行数: 7.895, 混乱度(CV): 0.329
# [234 (4)_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 8.74, 混乱度(CV): 0.247
# [234_det.jpg] 气孔: 190, 密度: 9.876e-05, 行数: 7.795, 混乱度(CV): 0.272
# [235 (2)_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 9.56, 混乱度(CV): 0.274
# [235 (3)_det.jpg] 气孔: 208, 密度: 1.081e-04, 行数: 8.81, 混乱度(CV): 0.272
# [235_det.jpg] 气孔: 200, 密度: 1.041e-04, 行数: 8.265, 混乱度(CV): 0.258
# [236 (2)_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.275, 混乱度(CV): 0.248
# [236 (3)_det.jpg] 气孔: 237, 密度: 1.233e-04, 行数: 10.035, 混乱度(CV): 0.261
# [236_det.jpg] 气孔: 360, 密度: 1.873e-04, 行数: 14.835, 混乱度(CV): 0.242
# [237 (2)_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.68, 混乱度(CV): 0.244
# [237 (3)_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 9.715, 混乱度(CV): 0.228
# [237_det.jpg] 气孔: 211, 密度: 1.098e-04, 行数: 8.905, 混乱度(CV): 0.243
# [238 (2)_det.jpg] 气孔: 232, 密度: 1.207e-04, 行数: 9.96, 混乱度(CV): 0.250
# [238 (3)_det.jpg] 气孔: 188, 密度: 9.782e-05, 行数: 8.25, 混乱度(CV): 0.230
# [238_det.jpg] 气孔: 180, 密度: 9.366e-05, 行数: 8.145, 混乱度(CV): 0.250
# [239 (2)_det.jpg] 气孔: 227, 密度: 1.181e-04, 行数: 9.85, 混乱度(CV): 0.298
# [239 (3)_det.jpg] 气孔: 294, 密度: 1.530e-04, 行数: 11.92, 混乱度(CV): 0.270
# [239_det.jpg] 气孔: 229, 密度: 1.190e-04, 行数: 9.655, 混乱度(CV): 0.273
# [240 (2)_det.jpg] 气孔: 196, 密度: 1.019e-04, 行数: 8.09, 混乱度(CV): 0.297
# [240 (3)_det.jpg] 气孔: 225, 密度: 1.171e-04, 行数: 9.84, 混乱度(CV): 0.322
# [240_det.jpg] 气孔: 259, 密度: 1.348e-04, 行数: 10.32, 混乱度(CV): 0.284
# [241 (2)_det.jpg] 气孔: 246, 密度: 1.279e-04, 行数: 9.98, 混乱度(CV): 0.212
# [241 (3)_det.jpg] 气孔: 194, 密度: 1.009e-04, 行数: 8.58, 混乱度(CV): 0.220
# [241_det.jpg] 气孔: 148, 密度: 7.693e-05, 行数: 6.735, 混乱度(CV): 0.289
# [242 (2)_det.jpg] 气孔: 278, 密度: 1.445e-04, 行数: 11.11, 混乱度(CV): 0.247
# [242 (3)_det.jpg] 气孔: 277, 密度: 1.441e-04, 行数: 10.48, 混乱度(CV): 0.265
# [242_det.jpg] 气孔: 284, 密度: 1.476e-04, 行数: 11.16, 混乱度(CV): 0.303
# [243 (2)_det.jpg] 气孔: 214, 密度: 1.112e-04, 行数: 8.945, 混乱度(CV): 0.260
# [243 (3)_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 9.745, 混乱度(CV): 0.212
# [243_det.jpg] 气孔: 227, 密度: 1.181e-04, 行数: 9.63, 混乱度(CV): 0.295
# [244 (2)_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 10.055, 混乱度(CV): 0.213
# [244 (3)_det.jpg] 气孔: 221, 密度: 1.149e-04, 行数: 9.18, 混乱度(CV): 0.202
# [244_det.jpg] 气孔: 214, 密度: 1.112e-04, 行数: 8.995, 混乱度(CV): 0.194
# [245 (2)_det.jpg] 气孔: 209, 密度: 1.089e-04, 行数: 9.195, 混乱度(CV): 0.264
# [245 (3)_det.jpg] 气孔: 175, 密度: 9.097e-05, 行数: 7.54, 混乱度(CV): 0.260
# [245 (4)_det.jpg] 气孔: 190, 密度: 9.876e-05, 行数: 8.475, 混乱度(CV): 0.281
# [245_det.jpg] 气孔: 197, 密度: 1.024e-04, 行数: 8.185, 混乱度(CV): 0.269
# [246 (2)_det.jpg] 气孔: 226, 密度: 1.175e-04, 行数: 8.815, 混乱度(CV): 0.288
# [246 (3)_det.jpg] 气孔: 222, 密度: 1.155e-04, 行数: 9.05, 混乱度(CV): 0.239
# [246 (4)_det.jpg] 气孔: 217, 密度: 1.129e-04, 行数: 8.68, 混乱度(CV): 0.210
# [246_det.jpg] 气孔: 254, 密度: 1.322e-04, 行数: 9.75, 混乱度(CV): 0.266
# [248 (2)_det.jpg] 气孔: 203, 密度: 1.055e-04, 行数: 8.645, 混乱度(CV): 0.222
# [248 (3)_det.jpg] 气孔: 174, 密度: 9.045e-05, 行数: 7.86, 混乱度(CV): 0.297
# [248_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 8.745, 混乱度(CV): 0.266
# [249 (2)_det.jpg] 气孔: 192, 密度: 9.967e-05, 行数: 8.395, 混乱度(CV): 0.214
# [249 (3)_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.105, 混乱度(CV): 0.299
# [249_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 9.165, 混乱度(CV): 0.219
# [250 (2)_det.jpg] 气孔: 181, 密度: 9.409e-05, 行数: 7.535, 混乱度(CV): 0.203
# [250 (3)_det.jpg] 气孔: 164, 密度: 8.533e-05, 行数: 7.375, 混乱度(CV): 0.320
# [250_det.jpg] 气孔: 177, 密度: 9.201e-05, 行数: 7.86, 混乱度(CV): 0.189
# [251 (2)_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 8.59, 混乱度(CV): 0.196
# [251 (3)_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.17, 混乱度(CV): 0.222
# [251_det.jpg] 气孔: 252, 密度: 1.310e-04, 行数: 10.105, 混乱度(CV): 0.187
# [252 (2)_det.jpg] 气孔: 174, 密度: 9.053e-05, 行数: 7.48, 混乱度(CV): 0.264
# [252 (3)_det.jpg] 气孔: 139, 密度: 7.232e-05, 行数: 6.375, 混乱度(CV): 0.283
# [252_det.jpg] 气孔: 190, 密度: 9.886e-05, 行数: 7.945, 混乱度(CV): 0.268
# [254 (2)_det.jpg] 气孔: 257, 密度: 1.336e-04, 行数: 10.235, 混乱度(CV): 0.206
# [254 (3)_det.jpg] 气孔: 197, 密度: 1.024e-04, 行数: 8.915, 混乱度(CV): 0.202
# [254_det.jpg] 气孔: 199, 密度: 1.035e-04, 行数: 8.67, 混乱度(CV): 0.165
# [255 (2)_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 9.76, 混乱度(CV): 0.331
# [255 (3)_det.jpg] 气孔: 327, 密度: 1.701e-04, 行数: 13.35, 混乱度(CV): 0.230
# [255 (4)_det.jpg] 气孔: 298, 密度: 1.551e-04, 行数: 11.845, 混乱度(CV): 0.198
# [255_det.jpg] 气孔: 284, 密度: 1.478e-04, 行数: 12.185, 混乱度(CV): 0.241
# [256 (2)_det.jpg] 气孔: 188, 密度: 9.772e-05, 行数: 7.905, 混乱度(CV): 0.217
# [256 (3)_det.jpg] 气孔: 205, 密度: 1.066e-04, 行数: 9.1, 混乱度(CV): 0.208
# [256_det.jpg] 气孔: 158, 密度: 8.221e-05, 行数: 7.425, 混乱度(CV): 0.285
# [257 (2)_det.jpg] 气孔: 176, 密度: 9.149e-05, 行数: 7.275, 混乱度(CV): 0.154
# [257 (3)_det.jpg] 气孔: 197, 密度: 1.024e-04, 行数: 8.03, 混乱度(CV): 0.189
# [257_det.jpg] 气孔: 250, 密度: 1.300e-04, 行数: 9.875, 混乱度(CV): 0.189
# [258 (2)_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.435, 混乱度(CV): 0.233
# [258 (3)_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 9.175, 混乱度(CV): 0.300
# [258 (4)_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 9.4, 混乱度(CV): 0.278
# [258_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 11.23, 混乱度(CV): 0.232
# [259 (2)_det.jpg] 气孔: 279, 密度: 1.450e-04, 行数: 11.375, 混乱度(CV): 0.275
# [259 (3)_det.jpg] 气孔: 244, 密度: 1.268e-04, 行数: 10.87, 混乱度(CV): 0.248
# [259_det.jpg] 气孔: 255, 密度: 1.326e-04, 行数: 10.49, 混乱度(CV): 0.272
# [260 (2)_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 8.955, 混乱度(CV): 0.242
# [260 (3)_det.jpg] 气孔: 250, 密度: 1.298e-04, 行数: 10.42, 混乱度(CV): 0.216
# [260_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 8.9, 混乱度(CV): 0.220
# [261 (2)_det.jpg] 气孔: 238, 密度: 1.237e-04, 行数: 10.11, 混乱度(CV): 0.214
# [261 (3)_det.jpg] 气孔: 203, 密度: 1.056e-04, 行数: 9.125, 混乱度(CV): 0.173
# [261 (4)_det.jpg] 气孔: 224, 密度: 1.164e-04, 行数: 9.68, 混乱度(CV): 0.215
# [261_det.jpg] 气孔: 182, 密度: 9.470e-05, 行数: 8.535, 混乱度(CV): 0.168
# [263 (2)_det.jpg] 气孔: 251, 密度: 1.303e-04, 行数: 10.465, 混乱度(CV): 0.231
# [263 (3)_det.jpg] 气孔: 260, 密度: 1.352e-04, 行数: 10.625, 混乱度(CV): 0.241
# [263 (4)_det.jpg] 气孔: 295, 密度: 1.535e-04, 行数: 11.75, 混乱度(CV): 0.243
# [263_det.jpg] 气孔: 307, 密度: 1.596e-04, 行数: 11.77, 混乱度(CV): 0.248
# [264 (2)_det.jpg] 气孔: 221, 密度: 1.150e-04, 行数: 8.515, 混乱度(CV): 0.168
# [264 (3)_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 8.18, 混乱度(CV): 0.214
# [264_det.jpg] 气孔: 222, 密度: 1.155e-04, 行数: 8.8, 混乱度(CV): 0.228
# [265 (2)_det.jpg] 气孔: 250, 密度: 1.301e-04, 行数: 10.135, 混乱度(CV): 0.197
# [265 (3)_det.jpg] 气孔: 196, 密度: 1.020e-04, 行数: 8.23, 混乱度(CV): 0.223
# [265_det.jpg] 气孔: 221, 密度: 1.149e-04, 行数: 9.035, 混乱度(CV): 0.210
# [266 (2)_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.265, 混乱度(CV): 0.177
# [266 (3)_det.jpg] 气孔: 196, 密度: 1.020e-04, 行数: 8.825, 混乱度(CV): 0.268
# [266_det.jpg] 气孔: 225, 密度: 1.170e-04, 行数: 9.32, 混乱度(CV): 0.236
# [267 (2)_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 10.595, 混乱度(CV): 0.189
# [267 (3)_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 11.215, 混乱度(CV): 0.236
# [267_det.jpg] 气孔: 266, 密度: 1.384e-04, 行数: 11.305, 混乱度(CV): 0.258
# [268 (2)_det.jpg] 气孔: 266, 密度: 1.383e-04, 行数: 11.03, 混乱度(CV): 0.195
# [268 (3)_det.jpg] 气孔: 251, 密度: 1.306e-04, 行数: 10.775, 混乱度(CV): 0.228
# [268_det.jpg] 气孔: 355, 密度: 1.845e-04, 行数: 13.9, 混乱度(CV): 0.260
# [269 (2)_det.jpg] 气孔: 228, 密度: 1.186e-04, 行数: 9.61, 混乱度(CV): 0.286
# [269 (3)_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.445, 混乱度(CV): 0.314
# [269_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 10.25, 混乱度(CV): 0.310
# [270 (2)_det.jpg] 气孔: 189, 密度: 9.824e-05, 行数: 8.325, 混乱度(CV): 0.262
# [270 (3)_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 10.8, 混乱度(CV): 0.275
# [270_det.jpg] 气孔: 224, 密度: 1.164e-04, 行数: 9.19, 混乱度(CV): 0.284
# [271 (2)_det.jpg] 气孔: 195, 密度: 1.014e-04, 行数: 8.445, 混乱度(CV): 0.294
# [271 (3)_det.jpg] 气孔: 254, 密度: 1.320e-04, 行数: 10.65, 混乱度(CV): 0.309
# [271_det.jpg] 气孔: 232, 密度: 1.206e-04, 行数: 10.03, 混乱度(CV): 0.271
# [272 (2)_det.jpg] 气孔: 271, 密度: 1.409e-04, 行数: 10.9, 混乱度(CV): 0.277
# [272 (3)_det.jpg] 气孔: 244, 密度: 1.270e-04, 行数: 10.12, 混乱度(CV): 0.246
# [272 (4)_det.jpg] 气孔: 233, 密度: 1.211e-04, 行数: 9.435, 混乱度(CV): 0.265
# [272_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 8.945, 混乱度(CV): 0.218
# [273 (2)_det.jpg] 气孔: 223, 密度: 1.159e-04, 行数: 8.34, 混乱度(CV): 0.168
# [273 (3)_det.jpg] 气孔: 221, 密度: 1.151e-04, 行数: 9.055, 混乱度(CV): 0.198
# [273_det.jpg] 气孔: 186, 密度: 9.678e-05, 行数: 7.695, 混乱度(CV): 0.195
# [274 (2)_det.jpg] 气孔: 182, 密度: 9.470e-05, 行数: 7.575, 混乱度(CV): 0.140
# [274 (3)_det.jpg] 气孔: 222, 密度: 1.155e-04, 行数: 8.8, 混乱度(CV): 0.225
# [274_det.jpg] 气孔: 180, 密度: 9.366e-05, 行数: 7.65, 混乱度(CV): 0.226
# [31 (2)_det.jpg] 气孔: 302, 密度: 1.571e-04, 行数: 11.785, 混乱度(CV): 0.184
# [31 (3)_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 10.565, 混乱度(CV): 0.193
# [31_det.jpg] 气孔: 283, 密度: 1.472e-04, 行数: 12.145, 混乱度(CV): 0.153
# [32 (2)_det.jpg] 气孔: 317, 密度: 1.649e-04, 行数: 12.725, 混乱度(CV): 0.184
# [32 (3)_det.jpg] 气孔: 353, 密度: 1.837e-04, 行数: 14.165, 混乱度(CV): 0.255
# [32_det.jpg] 气孔: 308, 密度: 1.603e-04, 行数: 13.005, 混乱度(CV): 0.259
# [33 (2)_det.jpg] 气孔: 266, 密度: 1.384e-04, 行数: 10.71, 混乱度(CV): 0.222
# [33_det.jpg] 气孔: 306, 密度: 1.592e-04, 行数: 12.28, 混乱度(CV): 0.204
# [34 (2)_det.jpg] 气孔: 243, 密度: 1.263e-04, 行数: 10.045, 混乱度(CV): 0.224
# [34 (3)_det.jpg] 气孔: 268, 密度: 1.393e-04, 行数: 10.875, 混乱度(CV): 0.224
# [34_det.jpg] 气孔: 250, 密度: 1.301e-04, 行数: 10.155, 混乱度(CV): 0.246
# [35 (2)_det.jpg] 气孔: 225, 密度: 1.171e-04, 行数: 9.44, 混乱度(CV): 0.256
# [35 (3)_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 9.72, 混乱度(CV): 0.223
# [35_det.jpg] 气孔: 189, 密度: 9.834e-05, 行数: 8.595, 混乱度(CV): 0.269
# [36 (2)_det.jpg] 气孔: 300, 密度: 1.561e-04, 行数: 12.295, 混乱度(CV): 0.253
# [36 (3)_det.jpg] 气孔: 311, 密度: 1.617e-04, 行数: 12.265, 混乱度(CV): 0.238
# [36_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 10.06, 混乱度(CV): 0.270
# [37 (2)_det.jpg] 气孔: 302, 密度: 1.571e-04, 行数: 12.405, 混乱度(CV): 0.251
# [37 (3)_det.jpg] 气孔: 398, 密度: 2.071e-04, 行数: 15.045, 混乱度(CV): 0.236
# [37_det.jpg] 气孔: 249, 密度: 1.296e-04, 行数: 10.235, 混乱度(CV): 0.261
# [38 (2)_det.jpg] 气孔: 218, 密度: 1.134e-04, 行数: 8.805, 混乱度(CV): 0.282
# [38 (3)_det.jpg] 气孔: 211, 密度: 1.098e-04, 行数: 9.01, 混乱度(CV): 0.291
# [38_det.jpg] 气孔: 279, 密度: 1.450e-04, 行数: 11.675, 混乱度(CV): 0.258
# [39 (2)_det.jpg] 气孔: 297, 密度: 1.545e-04, 行数: 12.055, 混乱度(CV): 0.242
# [39 (3)_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 11.54, 混乱度(CV): 0.220
# [39 (4)_det.jpg] 气孔: 274, 密度: 1.426e-04, 行数: 10.455, 混乱度(CV): 0.224
# [39 (5)_det.jpg] 气孔: 355, 密度: 1.847e-04, 行数: 12.94, 混乱度(CV): 0.165
# [40 (2)_det.jpg] 气孔: 260, 密度: 1.353e-04, 行数: 10.35, 混乱度(CV): 0.333
# [40 (3)_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 9.505, 混乱度(CV): 0.286
# [40_det.jpg] 气孔: 194, 密度: 1.009e-04, 行数: 7.65, 混乱度(CV): 0.274
# [41 (2)_det.jpg] 气孔: 277, 密度: 1.440e-04, 行数: 11.21, 混乱度(CV): 0.357
# [41 (3)_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 8.615, 混乱度(CV): 0.295
# [41_det.jpg] 气孔: 214, 密度: 1.113e-04, 行数: 8.6, 混乱度(CV): 0.307
# [42 (2)_det.jpg] 气孔: 218, 密度: 1.134e-04, 行数: 8.635, 混乱度(CV): 0.203
# [42 (3)_det.jpg] 气孔: 249, 密度: 1.296e-04, 行数: 10.38, 混乱度(CV): 0.191
# [42_det.jpg] 气孔: 246, 密度: 1.280e-04, 行数: 10.025, 混乱度(CV): 0.243
# [43 (2)_det.jpg] 气孔: 188, 密度: 9.772e-05, 行数: 7.98, 混乱度(CV): 0.215
# [43 (3)_det.jpg] 气孔: 160, 密度: 8.325e-05, 行数: 7.035, 混乱度(CV): 0.254
# [43_det.jpg] 气孔: 163, 密度: 8.481e-05, 行数: 7.055, 混乱度(CV): 0.213
# [44 (2)_det.jpg] 气孔: 175, 密度: 9.105e-05, 行数: 7.37, 混乱度(CV): 0.279
# [44 (3)_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.48, 混乱度(CV): 0.301
# [44_det.jpg] 气孔: 218, 密度: 1.134e-04, 行数: 8.73, 混乱度(CV): 0.252
# [45 (2)_det.jpg] 气孔: 244, 密度: 1.270e-04, 行数: 9.755, 混乱度(CV): 0.235
# [45 (3)_det.jpg] 气孔: 262, 密度: 1.363e-04, 行数: 10.225, 混乱度(CV): 0.288
# [45_det.jpg] 气孔: 261, 密度: 1.358e-04, 行数: 10.32, 混乱度(CV): 0.245
# [46 (2)_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 10.215, 混乱度(CV): 0.193
# [46 (3)_det.jpg] 气孔: 251, 密度: 1.306e-04, 行数: 10.435, 混乱度(CV): 0.203
# [46_det.jpg] 气孔: 274, 密度: 1.425e-04, 行数: 10.845, 混乱度(CV): 0.218
# [47 (2)_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 9.05, 混乱度(CV): 0.196
# [47 (3)_det.jpg] 气孔: 194, 密度: 1.009e-04, 行数: 8.24, 混乱度(CV): 0.206
# [47_det.jpg] 气孔: 242, 密度: 1.259e-04, 行数: 9.78, 混乱度(CV): 0.260
# [48 (2)_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 10.045, 混乱度(CV): 0.298
# [48 (3)_det.jpg] 气孔: 254, 密度: 1.322e-04, 行数: 10.2, 混乱度(CV): 0.298
# [48_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 9.41, 混乱度(CV): 0.311
# [49 (2)_det.jpg] 气孔: 294, 密度: 1.530e-04, 行数: 11.685, 混乱度(CV): 0.277
# [49 (3)_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 10.21, 混乱度(CV): 0.255
# [49_det.jpg] 气孔: 272, 密度: 1.415e-04, 行数: 10.505, 混乱度(CV): 0.255
# [50 (2)_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 11.435, 混乱度(CV): 0.207
# [50 (3)_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 10.755, 混乱度(CV): 0.205
# [50_det.jpg] 气孔: 296, 密度: 1.540e-04, 行数: 12.425, 混乱度(CV): 0.216
# [51 (2)_det.jpg] 气孔: 281, 密度: 1.462e-04, 行数: 11.51, 混乱度(CV): 0.273
# [51 (3)_det.jpg] 气孔: 277, 密度: 1.441e-04, 行数: 10.93, 混乱度(CV): 0.226
# [51_det.jpg] 气孔: 266, 密度: 1.384e-04, 行数: 10.915, 混乱度(CV): 0.244
# [52 (2)_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.515, 混乱度(CV): 0.277
# [52 (3)_det.jpg] 气孔: 283, 密度: 1.471e-04, 行数: 12.41, 混乱度(CV): 0.310
# [52_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 10.535, 混乱度(CV): 0.218
# [53 (2)_det.jpg] 气孔: 219, 密度: 1.138e-04, 行数: 9.65, 混乱度(CV): 0.229
# [53 (3)_det.jpg] 气孔: 260, 密度: 1.352e-04, 行数: 10.58, 混乱度(CV): 0.236
# [53_det.jpg] 气孔: 213, 密度: 1.107e-04, 行数: 9.325, 混乱度(CV): 0.282
# [54 (2)_det.jpg] 气孔: 254, 密度: 1.322e-04, 行数: 10.23, 混乱度(CV): 0.346
# [54 (3)_det.jpg] 气孔: 228, 密度: 1.185e-04, 行数: 9.64, 混乱度(CV): 0.347
# [54_det.jpg] 气孔: 179, 密度: 9.314e-05, 行数: 8.2, 混乱度(CV): 0.284
# [55 (2)_det.jpg] 气孔: 275, 密度: 1.429e-04, 行数: 11.19, 混乱度(CV): 0.284
# [55 (3)_det.jpg] 气孔: 320, 密度: 1.665e-04, 行数: 12.93, 混乱度(CV): 0.360
# [55_det.jpg] 气孔: 240, 密度: 1.248e-04, 行数: 9.935, 混乱度(CV): 0.328
# [56 (2)_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.08, 混乱度(CV): 0.265
# [56 (3)_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 8.61, 混乱度(CV): 0.266
# [56_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 9.39, 混乱度(CV): 0.247
# [57 (2)_det.jpg] 气孔: 289, 密度: 1.504e-04, 行数: 12.11, 混乱度(CV): 0.237
# [57 (3)_det.jpg] 气孔: 325, 密度: 1.691e-04, 行数: 12.73, 混乱度(CV): 0.298
# [57_det.jpg] 气孔: 313, 密度: 1.629e-04, 行数: 12.9, 混乱度(CV): 0.235
# [58 (2)_det.jpg] 气孔: 284, 密度: 1.478e-04, 行数: 11.145, 混乱度(CV): 0.238
# [58 (3)_det.jpg] 气孔: 253, 密度: 1.316e-04, 行数: 10.21, 混乱度(CV): 0.200
# [58 (4)_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 11.17, 混乱度(CV): 0.201
# [58_det.jpg] 气孔: 219, 密度: 1.139e-04, 行数: 9.24, 混乱度(CV): 0.188
# [59 (2)_det.jpg] 气孔: 160, 密度: 8.325e-05, 行数: 7.195, 混乱度(CV): 0.272
# [59 (3)_det.jpg] 气孔: 200, 密度: 1.040e-04, 行数: 7.945, 混乱度(CV): 0.199
# [59_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 7.895, 混乱度(CV): 0.289
# [60 (2)_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 10.07, 混乱度(CV): 0.227
# [60 (3)_det.jpg] 气孔: 258, 密度: 1.342e-04, 行数: 10.2, 混乱度(CV): 0.216
# [60_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.02, 混乱度(CV): 0.244
# [61 (2)_det.jpg] 气孔: 305, 密度: 1.587e-04, 行数: 11.75, 混乱度(CV): 0.284
# [61 (3)_det.jpg] 气孔: 348, 密度: 1.811e-04, 行数: 13.65, 混乱度(CV): 0.202
# [61_det.jpg] 气孔: 311, 密度: 1.618e-04, 行数: 12.22, 混乱度(CV): 0.234
# [62 (2)_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 10.55, 混乱度(CV): 0.300
# [62 (3)_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 10.095, 混乱度(CV): 0.285
# [62_det.jpg] 气孔: 234, 密度: 1.216e-04, 行数: 9.32, 混乱度(CV): 0.201
# [63 (2)_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 9.895, 混乱度(CV): 0.283
# [63 (3)_det.jpg] 气孔: 253, 密度: 1.316e-04, 行数: 10.335, 混乱度(CV): 0.242
# [63_det.jpg] 气孔: 289, 密度: 1.504e-04, 行数: 11.225, 混乱度(CV): 0.236
# [64 (2)_det.jpg] 气孔: 272, 密度: 1.415e-04, 行数: 11.175, 混乱度(CV): 0.238
# [64 (3)_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.045, 混乱度(CV): 0.226
# [64_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 9.21, 混乱度(CV): 0.269
# [65 (2)_det.jpg] 气孔: 357, 密度: 1.858e-04, 行数: 14.435, 混乱度(CV): 0.210
# [65 (3)_det.jpg] 气孔: 367, 密度: 1.910e-04, 行数: 13.85, 混乱度(CV): 0.246
# [65 (4)_det.jpg] 气孔: 386, 密度: 2.008e-04, 行数: 14.545, 混乱度(CV): 0.258
# [65 (5)_det.jpg] 气孔: 350, 密度: 1.819e-04, 行数: 13.88, 混乱度(CV): 0.256
# [65_det.jpg] 气孔: 311, 密度: 1.618e-04, 行数: 12.45, 混乱度(CV): 0.192
# [66 (2)_det.jpg] 气孔: 270, 密度: 1.403e-04, 行数: 10.24, 混乱度(CV): 0.158
# [66 (3)_det.jpg] 气孔: 267, 密度: 1.389e-04, 行数: 10.57, 混乱度(CV): 0.241
# [66 (4)_det.jpg] 气孔: 296, 密度: 1.540e-04, 行数: 11.575, 混乱度(CV): 0.228
# [66_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 9.685, 混乱度(CV): 0.211
# [67 (2)_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.585, 混乱度(CV): 0.257
# [67 (3)_det.jpg] 气孔: 218, 密度: 1.134e-04, 行数: 9.56, 混乱度(CV): 0.273
# [67_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.915, 混乱度(CV): 0.324
# [68 (2)_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 10.04, 混乱度(CV): 0.243
# [68 (3)_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 9.565, 混乱度(CV): 0.297
# [68_det.jpg] 气孔: 304, 密度: 1.582e-04, 行数: 12.03, 混乱度(CV): 0.221
# [69 (2)_det.jpg] 气孔: 327, 密度: 1.701e-04, 行数: 13.23, 混乱度(CV): 0.286
# [69 (3)_det.jpg] 气孔: 278, 密度: 1.445e-04, 行数: 10.97, 混乱度(CV): 0.295
# [69_det.jpg] 气孔: 253, 密度: 1.316e-04, 行数: 10.375, 混乱度(CV): 0.314
# [70 (2)_det.jpg] 气孔: 246, 密度: 1.280e-04, 行数: 9.7, 混乱度(CV): 0.267
# [70 (3)_det.jpg] 气孔: 232, 密度: 1.207e-04, 行数: 9.275, 混乱度(CV): 0.308
# [70_det.jpg] 气孔: 207, 密度: 1.077e-04, 行数: 8.71, 混乱度(CV): 0.237
# [71 (2)_det.jpg] 气孔: 219, 密度: 1.139e-04, 行数: 8.765, 混乱度(CV): 0.182
# [71 (3)_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 10.63, 混乱度(CV): 0.279
# [71_det.jpg] 气孔: 298, 密度: 1.551e-04, 行数: 11.59, 混乱度(CV): 0.194
# [72 (2)_det.jpg] 气孔: 261, 密度: 1.358e-04, 行数: 10.29, 混乱度(CV): 0.167
# [72 (3)_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 10.44, 混乱度(CV): 0.185
# [72_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.91, 混乱度(CV): 0.149
# [73 (2)_det.jpg] 气孔: 357, 密度: 1.856e-04, 行数: 13.66, 混乱度(CV): 0.226
# [73 (3)_det.jpg] 气孔: 310, 密度: 1.611e-04, 行数: 12.14, 混乱度(CV): 0.221
# [73_det.jpg] 气孔: 388, 密度: 2.019e-04, 行数: 14.68, 混乱度(CV): 0.250
# [74 (2)_det.jpg] 气孔: 265, 密度: 1.379e-04, 行数: 11.215, 混乱度(CV): 0.364
# [74 (3)_det.jpg] 气孔: 286, 密度: 1.487e-04, 行数: 10.895, 混乱度(CV): 0.313
# [74_det.jpg] 气孔: 314, 密度: 1.632e-04, 行数: 12.185, 混乱度(CV): 0.336
# [75 (2)_det.jpg] 气孔: 247, 密度: 1.284e-04, 行数: 10.81, 混乱度(CV): 0.286
# [75 (3)_det.jpg] 气孔: 218, 密度: 1.133e-04, 行数: 9.23, 混乱度(CV): 0.248
# [75_det.jpg] 气孔: 229, 密度: 1.192e-04, 行数: 9.23, 混乱度(CV): 0.241
# [76 (2)_det.jpg] 气孔: 230, 密度: 1.196e-04, 行数: 9.81, 混乱度(CV): 0.214
# [76 (3)_det.jpg] 气孔: 190, 密度: 9.876e-05, 行数: 7.99, 混乱度(CV): 0.227
# [76_det.jpg] 气孔: 256, 密度: 1.331e-04, 行数: 10.205, 混乱度(CV): 0.231
# [77 (2)_det.jpg] 气孔: 213, 密度: 1.107e-04, 行数: 8.915, 混乱度(CV): 0.243
# [77 (3)_det.jpg] 气孔: 288, 密度: 1.499e-04, 行数: 11.355, 混乱度(CV): 0.249
# [77_det.jpg] 气孔: 287, 密度: 1.493e-04, 行数: 11.29, 混乱度(CV): 0.244
# [78 (2)_det.jpg] 气孔: 201, 密度: 1.046e-04, 行数: 8.41, 混乱度(CV): 0.291
# [78 (3)_det.jpg] 气孔: 168, 密度: 8.741e-05, 行数: 7.75, 混乱度(CV): 0.247
# [78_det.jpg] 气孔: 196, 密度: 1.020e-04, 行数: 8.0, 混乱度(CV): 0.211
# [79 (2)_det.jpg] 气孔: 210, 密度: 1.093e-04, 行数: 8.9, 混乱度(CV): 0.313
# [79 (3)_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 8.935, 混乱度(CV): 0.350
# [79_det.jpg] 气孔: 251, 密度: 1.305e-04, 行数: 10.13, 混乱度(CV): 0.253
# [80 (2)_det.jpg] 气孔: 258, 密度: 1.342e-04, 行数: 10.43, 混乱度(CV): 0.208
# [80 (3)_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 10.02, 混乱度(CV): 0.229
# [80 (4)_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 9.4, 混乱度(CV): 0.212
# [80_det.jpg] 气孔: 194, 密度: 1.008e-04, 行数: 8.46, 混乱度(CV): 0.251
# [81 (2)_det.jpg] 气孔: 329, 密度: 1.712e-04, 行数: 12.48, 混乱度(CV): 0.255
# [81 (3)_det.jpg] 气孔: 320, 密度: 1.665e-04, 行数: 12.61, 混乱度(CV): 0.198
# [81_det.jpg] 气孔: 327, 密度: 1.700e-04, 行数: 12.415, 混乱度(CV): 0.234
# [82 (2)_det.jpg] 气孔: 300, 密度: 1.561e-04, 行数: 12.265, 混乱度(CV): 0.304
# [82 (3)_det.jpg] 气孔: 285, 密度: 1.481e-04, 行数: 11.475, 混乱度(CV): 0.298
# [82_det.jpg] 气孔: 264, 密度: 1.374e-04, 行数: 10.82, 混乱度(CV): 0.327
# [83 (2)_det.jpg] 气孔: 270, 密度: 1.405e-04, 行数: 11.26, 混乱度(CV): 0.272
# [83 (3)_det.jpg] 气孔: 305, 密度: 1.587e-04, 行数: 12.44, 混乱度(CV): 0.320
# [83_det.jpg] 气孔: 224, 密度: 1.163e-04, 行数: 9.215, 混乱度(CV): 0.298
# [84 (2)_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.425, 混乱度(CV): 0.246
# [84 (3)_det.jpg] 气孔: 251, 密度: 1.306e-04, 行数: 10.505, 混乱度(CV): 0.275
# [84 (4)_det.jpg] 气孔: 213, 密度: 1.107e-04, 行数: 8.845, 混乱度(CV): 0.231
# [84_det.jpg] 气孔: 275, 密度: 1.432e-04, 行数: 10.73, 混乱度(CV): 0.268
# [85 (2)_det.jpg] 气孔: 196, 密度: 1.020e-04, 行数: 8.21, 混乱度(CV): 0.268
# [85 (3)_det.jpg] 气孔: 217, 密度: 1.129e-04, 行数: 8.93, 混乱度(CV): 0.229
# [85_det.jpg] 气孔: 182, 密度: 9.461e-05, 行数: 8.01, 混乱度(CV): 0.247
# [86 (2)_det.jpg] 气孔: 149, 密度: 7.745e-05, 行数: 7.385, 混乱度(CV): 0.373
# [86 (3)_det.jpg] 气孔: 188, 密度: 9.782e-05, 行数: 8.6, 混乱度(CV): 0.256
# [86_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.9, 混乱度(CV): 0.294
# [87 (2)_det.jpg] 气孔: 234, 密度: 1.216e-04, 行数: 9.285, 混乱度(CV): 0.198
# [87 (3)_det.jpg] 气孔: 210, 密度: 1.093e-04, 行数: 9.21, 混乱度(CV): 0.246
# [87_det.jpg] 气孔: 159, 密度: 8.273e-05, 行数: 6.905, 混乱度(CV): 0.253
# [88 (2)_det.jpg] 气孔: 249, 密度: 1.294e-04, 行数: 10.99, 混乱度(CV): 0.298
# [88 (3)_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.295, 混乱度(CV): 0.259
# [88_det.jpg] 气孔: 187, 密度: 9.721e-05, 行数: 8.515, 混乱度(CV): 0.287
# [89 (2)_det.jpg] 气孔: 231, 密度: 1.201e-04, 行数: 10.105, 混乱度(CV): 0.245
# [89 (3)_det.jpg] 气孔: 198, 密度: 1.029e-04, 行数: 8.7, 混乱度(CV): 0.304
# [89 (4)_det.jpg] 气孔: 277, 密度: 1.441e-04, 行数: 12.32, 混乱度(CV): 0.272
# [89_det.jpg] 气孔: 272, 密度: 1.415e-04, 行数: 11.355, 混乱度(CV): 0.305
# [90 (2)_det.jpg] 气孔: 293, 密度: 1.523e-04, 行数: 12.255, 混乱度(CV): 0.338
# [90 (3)_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 9.665, 混乱度(CV): 0.284
# [90 (4)_det.jpg] 气孔: 204, 密度: 1.060e-04, 行数: 9.11, 混乱度(CV): 0.264
# [90_det.jpg] 气孔: 334, 密度: 1.738e-04, 行数: 13.165, 混乱度(CV): 0.277
#
# 已处理 631 张图片，结果保存到 海南叶片气孔统计.csv
# [1251_1_det.jpg] 气孔: 284, 密度: 1.478e-04, 行数: 11.37, 混乱度(CV): 0.227
# [1251_2_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.68, 混乱度(CV): 0.288
# [1251_3_det.jpg] 气孔: 330, 密度: 1.717e-04, 行数: 13.035, 混乱度(CV): 0.264
# [1251_4_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.28, 混乱度(CV): 0.223
# [1251_5_det.jpg] 气孔: 299, 密度: 1.556e-04, 行数: 11.76, 混乱度(CV): 0.246
# [1251_6_det.jpg] 气孔: 234, 密度: 1.218e-04, 行数: 9.945, 混乱度(CV): 0.318
# [1251_7_det.jpg] 气孔: 262, 密度: 1.363e-04, 行数: 10.93, 混乱度(CV): 0.239
# [1252_1_det.jpg] 气孔: 213, 密度: 1.108e-04, 行数: 9.71, 混乱度(CV): 0.287
# [1252_2_det.jpg] 气孔: 251, 密度: 1.306e-04, 行数: 11.18, 混乱度(CV): 0.270
# [1252_3_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 9.66, 混乱度(CV): 0.241
# [1252_4_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 9.885, 混乱度(CV): 0.238
# [1253_1_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.88, 混乱度(CV): 0.280
# [1253_2_det.jpg] 气孔: 159, 密度: 8.273e-05, 行数: 7.71, 混乱度(CV): 0.299
# [1253_3_det.jpg] 气孔: 210, 密度: 1.093e-04, 行数: 9.39, 混乱度(CV): 0.217
# [1253_4_det.jpg] 气孔: 167, 密度: 8.689e-05, 行数: 7.57, 混乱度(CV): 0.236
# [1253_5_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.275, 混乱度(CV): 0.167
# [1254_1_det.jpg] 气孔: 276, 密度: 1.436e-04, 行数: 9.88, 混乱度(CV): 0.179
# [1254_2_det.jpg] 气孔: 251, 密度: 1.306e-04, 行数: 10.38, 混乱度(CV): 0.247
# [1254_3_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.735, 混乱度(CV): 0.302
# [1254_4_det.jpg] 气孔: 204, 密度: 1.060e-04, 行数: 8.405, 混乱度(CV): 0.266
# [1254_5_det.jpg] 气孔: 198, 密度: 1.030e-04, 行数: 8.74, 混乱度(CV): 0.195
# [1255_1_det.jpg] 气孔: 249, 密度: 1.296e-04, 行数: 10.65, 混乱度(CV): 0.219
# [1255_2_det.jpg] 气孔: 206, 密度: 1.072e-04, 行数: 9.015, 混乱度(CV): 0.207
# [1255_3_det.jpg] 气孔: 229, 密度: 1.192e-04, 行数: 10.375, 混乱度(CV): 0.240
# [1255_4_det.jpg] 气孔: 241, 密度: 1.254e-04, 行数: 10.295, 混乱度(CV): 0.230
# [1255_5_det.jpg] 气孔: 187, 密度: 9.730e-05, 行数: 8.2, 混乱度(CV): 0.234
# [1256_1_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.14, 混乱度(CV): 0.206
# [1256_2_det.jpg] 气孔: 225, 密度: 1.171e-04, 行数: 10.205, 混乱度(CV): 0.218
# [1256_3_det.jpg] 气孔: 180, 密度: 9.366e-05, 行数: 7.985, 混乱度(CV): 0.221
# [1256_4_det.jpg] 气孔: 190, 密度: 9.886e-05, 行数: 8.445, 混乱度(CV): 0.290
# [1256_5_det.jpg] 气孔: 179, 密度: 9.314e-05, 行数: 8.065, 混乱度(CV): 0.251
# [1257_1_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.91, 混乱度(CV): 0.255
# [1257_2_det.jpg] 气孔: 168, 密度: 8.741e-05, 行数: 7.89, 混乱度(CV): 0.272
# [1257_3_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 9.775, 混乱度(CV): 0.216
# [1257_4_det.jpg] 气孔: 179, 密度: 9.314e-05, 行数: 8.07, 混乱度(CV): 0.249
# [1257_5_det.jpg] 气孔: 150, 密度: 7.805e-05, 行数: 7.37, 混乱度(CV): 0.243
# [1258_1_det.jpg] 气孔: 295, 密度: 1.535e-04, 行数: 12.425, 混乱度(CV): 0.254
# [1258_2_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 10.875, 混乱度(CV): 0.234
# [1258_3_det.jpg] 气孔: 326, 密度: 1.696e-04, 行数: 13.07, 混乱度(CV): 0.248
# [1258_4_det.jpg] 气孔: 289, 密度: 1.504e-04, 行数: 11.545, 混乱度(CV): 0.226
# [1258_5_det.jpg] 气孔: 265, 密度: 1.379e-04, 行数: 10.98, 混乱度(CV): 0.263
# [1259_+1_det.jpg] 气孔: 242, 密度: 1.259e-04, 行数: 10.03, 混乱度(CV): 0.182
# [1259_2_det.jpg] 气孔: 263, 密度: 1.368e-04, 行数: 11.585, 混乱度(CV): 0.228
# [1259_3_det.jpg] 气孔: 250, 密度: 1.301e-04, 行数: 10.35, 混乱度(CV): 0.237
# [1259_4_det.jpg] 气孔: 301, 密度: 1.566e-04, 行数: 12.815, 混乱度(CV): 0.237
# [1259_5_det.jpg] 气孔: 237, 密度: 1.233e-04, 行数: 9.985, 混乱度(CV): 0.220
# [1260_1_det.jpg] 气孔: 261, 密度: 1.358e-04, 行数: 11.0, 混乱度(CV): 0.205
# [1260_2_det.jpg] 气孔: 262, 密度: 1.363e-04, 行数: 11.16, 混乱度(CV): 0.287
# [1260_3_det.jpg] 气孔: 251, 密度: 1.306e-04, 行数: 10.895, 混乱度(CV): 0.233
# [1260_4_det.jpg] 气孔: 259, 密度: 1.348e-04, 行数: 11.1, 混乱度(CV): 0.176
# [1260_5_det.jpg] 气孔: 341, 密度: 1.774e-04, 行数: 13.85, 混乱度(CV): 0.202
# [1261_1_det.jpg] 气孔: 178, 密度: 9.262e-05, 行数: 7.925, 混乱度(CV): 0.232
# [1261_2_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.765, 混乱度(CV): 0.270
# [1261_3_det.jpg] 气孔: 230, 密度: 1.197e-04, 行数: 9.215, 混乱度(CV): 0.199
# [1261_4_det.jpg] 气孔: 272, 密度: 1.415e-04, 行数: 11.68, 混乱度(CV): 0.201
# [1261_5_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 10.635, 混乱度(CV): 0.228
# [1262_1_det.jpg] 气孔: 297, 密度: 1.545e-04, 行数: 11.93, 混乱度(CV): 0.241
# [1262_2_det.jpg] 气孔: 214, 密度: 1.113e-04, 行数: 9.17, 混乱度(CV): 0.212
# [1262_3_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 9.8, 混乱度(CV): 0.205
# [1262_4_det.jpg] 气孔: 253, 密度: 1.316e-04, 行数: 10.46, 混乱度(CV): 0.240
# [1262_5_det.jpg] 气孔: 211, 密度: 1.098e-04, 行数: 9.315, 混乱度(CV): 0.224
# [1263_1_det.jpg] 气孔: 295, 密度: 1.533e-04, 行数: 12.565, 混乱度(CV): 0.249
# [1263_2_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 10.23, 混乱度(CV): 0.226
# [1263_3_det.jpg] 气孔: 299, 密度: 1.556e-04, 行数: 12.94, 混乱度(CV): 0.208
# [1263_4_det.jpg] 气孔: 296, 密度: 1.540e-04, 行数: 13.03, 混乱度(CV): 0.226
# [1263_5_det.jpg] 气孔: 280, 密度: 1.457e-04, 行数: 11.89, 混乱度(CV): 0.239
# [1264_1_det.jpg] 气孔: 289, 密度: 1.504e-04, 行数: 12.25, 混乱度(CV): 0.234
# [1264_2_det.jpg] 气孔: 267, 密度: 1.389e-04, 行数: 11.895, 混乱度(CV): 0.244
# [1264_3_det.jpg] 气孔: 336, 密度: 1.748e-04, 行数: 14.375, 混乱度(CV): 0.250
# [1264_4_det.jpg] 气孔: 287, 密度: 1.493e-04, 行数: 12.59, 混乱度(CV): 0.217
# [1264_5_det.jpg] 气孔: 263, 密度: 1.368e-04, 行数: 11.87, 混乱度(CV): 0.214
# [1265_1_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 11.535, 混乱度(CV): 0.214
# [1265_2_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 11.345, 混乱度(CV): 0.257
# [1265_3_det.jpg] 气孔: 251, 密度: 1.305e-04, 行数: 10.895, 混乱度(CV): 0.219
# [1265_4_det.jpg] 气孔: 218, 密度: 1.133e-04, 行数: 9.375, 混乱度(CV): 0.216
# [1265_5_det.jpg] 气孔: 327, 密度: 1.701e-04, 行数: 13.7, 混乱度(CV): 0.214
# [1266_1_det.jpg] 气孔: 186, 密度: 9.678e-05, 行数: 8.54, 混乱度(CV): 0.197
# [1266_2_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 9.71, 混乱度(CV): 0.209
# [1266_3_det.jpg] 气孔: 246, 密度: 1.280e-04, 行数: 10.635, 混乱度(CV): 0.268
# [1266_4_det.jpg] 气孔: 207, 密度: 1.077e-04, 行数: 9.26, 混乱度(CV): 0.212
# [1266_5_det.jpg] 气孔: 263, 密度: 1.368e-04, 行数: 11.395, 混乱度(CV): 0.243
# [1268_1_det.jpg] 气孔: 289, 密度: 1.504e-04, 行数: 12.33, 混乱度(CV): 0.223
# [1268_2_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 10.005, 混乱度(CV): 0.219
# [1268_3_det.jpg] 气孔: 203, 密度: 1.056e-04, 行数: 8.89, 混乱度(CV): 0.276
# [1268_4_det.jpg] 气孔: 288, 密度: 1.499e-04, 行数: 12.14, 混乱度(CV): 0.207
# [1268_5_det.jpg] 气孔: 292, 密度: 1.519e-04, 行数: 12.025, 混乱度(CV): 0.235
# [710 _4_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 12.23, 混乱度(CV): 0.313
# [710_1_det.jpg] 气孔: 219, 密度: 1.142e-04, 行数: 10.155, 混乱度(CV): 0.210
# [710_2_det.jpg] 气孔: 275, 密度: 1.429e-04, 行数: 11.985, 混乱度(CV): 0.256
# [710_3_det.jpg] 气孔: 227, 密度: 1.180e-04, 行数: 10.67, 混乱度(CV): 0.263
# [711_1_det.jpg] 气孔: 227, 密度: 1.181e-04, 行数: 9.365, 混乱度(CV): 0.219
# ...
# [832_4_det.jpg] 气孔: 317, 密度: 1.649e-04, 行数: 12.16, 混乱度(CV): 0.154
# [833_1_det.jpg] 气孔: 315, 密度: 1.639e-04, 行数: 12.815, 混乱度(CV): 0.276
# [833_2_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 11.725, 混乱度(CV): 0.241
# [833_3_det.jpg] 气孔: 284, 密度: 1.478e-04, 行数: 11.955, 混乱度(CV): 0.239
# [833_4_det.jpg] 气孔: 357, 密度: 1.858e-04, 行数: 14.125, 混乱度(CV): 0.175
# [834_1_det.jpg] 气孔: 316, 密度: 1.644e-04, 行数: 12.435, 混乱度(CV): 0.251
# [834_2_det.jpg] 气孔: 286, 密度: 1.487e-04, 行数: 11.77, 混乱度(CV): 0.188
# [834_3_det.jpg] 气孔: 316, 密度: 1.644e-04, 行数: 12.32, 混乱度(CV): 0.226
# [834_4_det.jpg] 气孔: 238, 密度: 1.237e-04, 行数: 9.915, 混乱度(CV): 0.241
# [835_1_det.jpg] 气孔: 237, 密度: 1.232e-04, 行数: 9.7, 混乱度(CV): 0.201
# [835_2_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 10.135, 混乱度(CV): 0.198
# [835_3_det.jpg] 气孔: 206, 密度: 1.072e-04, 行数: 8.605, 混乱度(CV): 0.203
# [835_4_det.jpg] 气孔: 278, 密度: 1.445e-04, 行数: 11.07, 混乱度(CV): 0.168
# [836_1_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 10.335, 混乱度(CV): 0.207
# [836_2_det.jpg] 气孔: 225, 密度: 1.171e-04, 行数: 10.015, 混乱度(CV): 0.235
# [836_3_det.jpg] 气孔: 283, 密度: 1.472e-04, 行数: 12.105, 混乱度(CV): 0.278
# [836_4_det.jpg] 气孔: 229, 密度: 1.192e-04, 行数: 9.925, 混乱度(CV): 0.239
# [837_1_det.jpg] 气孔: 250, 密度: 1.301e-04, 行数: 10.15, 混乱度(CV): 0.190
# [837_2_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 10.425, 混乱度(CV): 0.232
# [837_3_det.jpg] 气孔: 274, 密度: 1.424e-04, 行数: 11.075, 混乱度(CV): 0.196
# [837_4_det.jpg] 气孔: 287, 密度: 1.492e-04, 行数: 11.915, 混乱度(CV): 0.195
# [838_1_det.jpg] 气孔: 218, 密度: 1.134e-04, 行数: 9.745, 混乱度(CV): 0.231
# [838_2_det.jpg] 气孔: 256, 密度: 1.331e-04, 行数: 11.08, 混乱度(CV): 0.183
# [838_3_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.895, 混乱度(CV): 0.255
# [838_4_det.jpg] 气孔: 215, 密度: 1.118e-04, 行数: 9.15, 混乱度(CV): 0.268
# [839_1_det.jpg] 气孔: 239, 密度: 1.242e-04, 行数: 9.905, 混乱度(CV): 0.241
# [839_2_det.jpg] 气孔: 323, 密度: 1.681e-04, 行数: 12.87, 混乱度(CV): 0.205
# [840_1_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.95, 混乱度(CV): 0.216
# [840_2_det.jpg] 气孔: 268, 密度: 1.394e-04, 行数: 11.335, 混乱度(CV): 0.244
# [840_3_det.jpg] 气孔: 260, 密度: 1.352e-04, 行数: 11.32, 混乱度(CV): 0.278
# [840_4_det.jpg] 气孔: 289, 密度: 1.502e-04, 行数: 12.82, 混乱度(CV): 0.229
# [841_1_det.jpg] 气孔: 330, 密度: 1.717e-04, 行数: 13.245, 混乱度(CV): 0.204
# [841_2_det.jpg] 气孔: 205, 密度: 1.067e-04, 行数: 9.205, 混乱度(CV): 0.212
# [841_3_det.jpg] 气孔: 302, 密度: 1.571e-04, 行数: 12.17, 混乱度(CV): 0.170
# [841_4_det.jpg] 气孔: 308, 密度: 1.603e-04, 行数: 12.235, 混乱度(CV): 0.187
# [841_5_det.jpg] 气孔: 199, 密度: 1.035e-04, 行数: 8.675, 混乱度(CV): 0.248
# [842_1_det.jpg] 气孔: 244, 密度: 1.270e-04, 行数: 10.675, 混乱度(CV): 0.252
# [842_2_det.jpg] 气孔: 235, 密度: 1.223e-04, 行数: 10.145, 混乱度(CV): 0.272
# [842_3_det.jpg] 气孔: 264, 密度: 1.372e-04, 行数: 11.695, 混乱度(CV): 0.254
# [842_4_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 10.66, 混乱度(CV): 0.288
# [842_5_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.965, 混乱度(CV): 0.275
# [843_1_det.jpg] 气孔: 270, 密度: 1.405e-04, 行数: 11.36, 混乱度(CV): 0.330
# [843_2_det.jpg] 气孔: 276, 密度: 1.436e-04, 行数: 11.97, 混乱度(CV): 0.301
# [843_3_det.jpg] 气孔: 276, 密度: 1.436e-04, 行数: 11.785, 混乱度(CV): 0.370
# [843_4_det.jpg] 气孔: 311, 密度: 1.618e-04, 行数: 12.81, 混乱度(CV): 0.374
# [844_1_det.jpg] 气孔: 215, 密度: 1.118e-04, 行数: 9.02, 混乱度(CV): 0.302
# [844_2_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 12.08, 混乱度(CV): 0.264
# [844_3_det.jpg] 气孔: 370, 密度: 1.925e-04, 行数: 14.52, 混乱度(CV): 0.294
# [844_4_det.jpg] 气孔: 178, 密度: 9.262e-05, 行数: 8.295, 混乱度(CV): 0.354
# [845_1_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.695, 混乱度(CV): 0.232
# [845_2_det.jpg] 气孔: 209, 密度: 1.087e-04, 行数: 8.69, 混乱度(CV): 0.214
# [845_3_det.jpg] 气孔: 199, 密度: 1.034e-04, 行数: 8.8, 混乱度(CV): 0.242
# [845_4_det.jpg] 气孔: 184, 密度: 9.574e-05, 行数: 8.375, 混乱度(CV): 0.231
# [846_1_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 11.535, 混乱度(CV): 0.237
# [846_2_det.jpg] 气孔: 236, 密度: 1.228e-04, 行数: 10.02, 混乱度(CV): 0.274
# [846_3_det.jpg] 气孔: 242, 密度: 1.259e-04, 行数: 9.96, 混乱度(CV): 0.211
# [846_4_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 9.085, 混乱度(CV): 0.279
# [847_1_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.995, 混乱度(CV): 0.261
# [847_2_det.jpg] 气孔: 227, 密度: 1.181e-04, 行数: 9.94, 混乱度(CV): 0.259
# [847_3_det.jpg] 气孔: 209, 密度: 1.087e-04, 行数: 9.11, 混乱度(CV): 0.236
# [847_4_det.jpg] 气孔: 259, 密度: 1.348e-04, 行数: 11.205, 混乱度(CV): 0.267
# [848_1_det.jpg] 气孔: 326, 密度: 1.696e-04, 行数: 13.31, 混乱度(CV): 0.250
# [848_2_det.jpg] 气孔: 280, 密度: 1.455e-04, 行数: 11.89, 混乱度(CV): 0.219
# [848_3_det.jpg] 气孔: 329, 密度: 1.712e-04, 行数: 12.895, 混乱度(CV): 0.263
# [848_4_det.jpg] 气孔: 416, 密度: 2.165e-04, 行数: 15.41, 混乱度(CV): 0.201
# [849_1_det.jpg] 气孔: 321, 密度: 1.670e-04, 行数: 12.7, 混乱度(CV): 0.232
# [849_2_det.jpg] 气孔: 324, 密度: 1.686e-04, 行数: 13.005, 混乱度(CV): 0.220
# [849_3_det.jpg] 气孔: 201, 密度: 1.046e-04, 行数: 9.185, 混乱度(CV): 0.218
# [849_4_det.jpg] 气孔: 305, 密度: 1.587e-04, 行数: 12.38, 混乱度(CV): 0.227
# [849_5_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 11.925, 混乱度(CV): 0.232
# [850_1_det.jpg] 气孔: 262, 密度: 1.363e-04, 行数: 11.94, 混乱度(CV): 0.232
# [850_2_det.jpg] 气孔: 288, 密度: 1.499e-04, 行数: 11.625, 混乱度(CV): 0.203
# [850_3_det.jpg] 气孔: 343, 密度: 1.785e-04, 行数: 14.56, 混乱度(CV): 0.282
# [850_4_det.jpg] 气孔: 334, 密度: 1.738e-04, 行数: 13.92, 混乱度(CV): 0.260
# [850_5_det.jpg] 气孔: 281, 密度: 1.461e-04, 行数: 12.41, 混乱度(CV): 0.218
# [851_1_det.jpg] 气孔: 221, 密度: 1.150e-04, 行数: 10.52, 混乱度(CV): 0.211
# [851_2_det.jpg] 气孔: 288, 密度: 1.499e-04, 行数: 12.885, 混乱度(CV): 0.207
# [851_3_det.jpg] 气孔: 253, 密度: 1.315e-04, 行数: 10.74, 混乱度(CV): 0.266
# [851_4_det.jpg] 气孔: 251, 密度: 1.305e-04, 行数: 11.03, 混乱度(CV): 0.238
# [852_1_det.jpg] 气孔: 281, 密度: 1.462e-04, 行数: 12.245, 混乱度(CV): 0.193
# [852_2_det.jpg] 气孔: 239, 密度: 1.244e-04, 行数: 10.985, 混乱度(CV): 0.204
# [853_1_det.jpg] 气孔: 308, 密度: 1.603e-04, 行数: 12.675, 混乱度(CV): 0.193
# [853_2_det.jpg] 气孔: 393, 密度: 2.045e-04, 行数: 15.56, 混乱度(CV): 0.185
# [853_3_det.jpg] 气孔: 341, 密度: 1.773e-04, 行数: 14.555, 混乱度(CV): 0.198
# [853_4_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 9.66, 混乱度(CV): 0.218
# [854_1_det.jpg] 气孔: 295, 密度: 1.535e-04, 行数: 11.805, 混乱度(CV): 0.208
# [854_2_det.jpg] 气孔: 309, 密度: 1.608e-04, 行数: 12.77, 混乱度(CV): 0.269
# [854_3_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.75, 混乱度(CV): 0.270
# [854_4_det.jpg] 气孔: 262, 密度: 1.363e-04, 行数: 10.37, 混乱度(CV): 0.259
# [855_1_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 12.47, 混乱度(CV): 0.232
# [855_2_det.jpg] 气孔: 288, 密度: 1.499e-04, 行数: 11.665, 混乱度(CV): 0.264
# [855_3_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 11.885, 混乱度(CV): 0.234
# [855_4_det.jpg] 气孔: 249, 密度: 1.296e-04, 行数: 10.975, 混乱度(CV): 0.256
# [855_5_det.jpg] 气孔: 258, 密度: 1.341e-04, 行数: 10.915, 混乱度(CV): 0.253
# [856_1_det.jpg] 气孔: 351, 密度: 1.826e-04, 行数: 13.955, 混乱度(CV): 0.181
# [856_2_det.jpg] 气孔: 305, 密度: 1.587e-04, 行数: 12.725, 混乱度(CV): 0.172
# [856_3_det.jpg] 气孔: 295, 密度: 1.535e-04, 行数: 12.99, 混乱度(CV): 0.207
# [856_4_det.jpg] 气孔: 285, 密度: 1.483e-04, 行数: 12.785, 混乱度(CV): 0.207
# [857_1_det.jpg] 气孔: 197, 密度: 1.024e-04, 行数: 8.995, 混乱度(CV): 0.293
# [857_2_det.jpg] 气孔: 253, 密度: 1.316e-04, 行数: 11.435, 混乱度(CV): 0.272
# [857_3_det.jpg] 气孔: 227, 密度: 1.181e-04, 行数: 9.84, 混乱度(CV): 0.313
# [857_4_det.jpg] 气孔: 247, 密度: 1.285e-04, 行数: 11.285, 混乱度(CV): 0.263
# [857_5_det.jpg] 气孔: 210, 密度: 1.093e-04, 行数: 9.345, 混乱度(CV): 0.247
# [858_1_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 8.065, 混乱度(CV): 0.225
# [858_2_det.jpg] 气孔: 230, 密度: 1.197e-04, 行数: 9.565, 混乱度(CV): 0.250
# [858_3_det.jpg] 气孔: 165, 密度: 8.585e-05, 行数: 7.245, 混乱度(CV): 0.295
# [858_4_det.jpg] 气孔: 151, 密度: 7.857e-05, 行数: 6.84, 混乱度(CV): 0.309
# [859_1_det.jpg] 气孔: 265, 密度: 1.379e-04, 行数: 10.855, 混乱度(CV): 0.179
# [859_2_det.jpg] 气孔: 241, 密度: 1.254e-04, 行数: 10.49, 混乱度(CV): 0.187
# [859_3_det.jpg] 气孔: 260, 密度: 1.353e-04, 行数: 10.655, 混乱度(CV): 0.170
# [859_4_det.jpg] 气孔: 308, 密度: 1.603e-04, 行数: 12.345, 混乱度(CV): 0.226
# [859_5_det.jpg] 气孔: 243, 密度: 1.264e-04, 行数: 10.005, 混乱度(CV): 0.239
# [860_1_det.jpg] 气孔: 274, 密度: 1.426e-04, 行数: 11.02, 混乱度(CV): 0.190
# [860_2_det.jpg] 气孔: 173, 密度: 9.001e-05, 行数: 8.01, 混乱度(CV): 0.214
# [860_3_det.jpg] 气孔: 203, 密度: 1.056e-04, 行数: 9.225, 混乱度(CV): 0.200
# [860_4_det.jpg] 气孔: 178, 密度: 9.262e-05, 行数: 7.62, 混乱度(CV): 0.213
# [860_5_det.jpg] 气孔: 192, 密度: 9.990e-05, 行数: 8.85, 混乱度(CV): 0.242
# [861_1_det.jpg] 气孔: 324, 密度: 1.686e-04, 行数: 13.225, 混乱度(CV): 0.190
# [861_2_det.jpg] 气孔: 409, 密度: 2.128e-04, 行数: 15.815, 混乱度(CV): 0.146
# [861_3_det.jpg] 气孔: 312, 密度: 1.623e-04, 行数: 11.95, 混乱度(CV): 0.251
# [861_4_det.jpg] 气孔: 340, 密度: 1.769e-04, 行数: 12.945, 混乱度(CV): 0.191
# [862_1_det.jpg] 气孔: 223, 密度: 1.161e-04, 行数: 10.42, 混乱度(CV): 0.271
# [862_2_det.jpg] 气孔: 229, 密度: 1.190e-04, 行数: 10.335, 混乱度(CV): 0.322
# [862_3_det.jpg] 气孔: 256, 密度: 1.332e-04, 行数: 11.085, 混乱度(CV): 0.313
# [862_4_det.jpg] 气孔: 285, 密度: 1.483e-04, 行数: 12.035, 混乱度(CV): 0.273
# [863_1_det.jpg] 气孔: 188, 密度: 9.782e-05, 行数: 8.595, 混乱度(CV): 0.203
# [863_2_det.jpg] 气孔: 177, 密度: 9.210e-05, 行数: 7.845, 混乱度(CV): 0.194
# [863_3_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 8.21, 混乱度(CV): 0.244
# [863_4_det.jpg] 气孔: 146, 密度: 7.597e-05, 行数: 6.635, 混乱度(CV): 0.268
# [864_1_det.jpg] 气孔: 197, 密度: 1.025e-04, 行数: 9.005, 混乱度(CV): 0.189
# [864_2_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 11.315, 混乱度(CV): 0.255
# [864_3_det.jpg] 气孔: 213, 密度: 1.108e-04, 行数: 9.345, 混乱度(CV): 0.215
# [864_4_det.jpg] 气孔: 213, 密度: 1.108e-04, 行数: 9.355, 混乱度(CV): 0.176
# [864_5_det.jpg] 气孔: 170, 密度: 8.845e-05, 行数: 8.065, 混乱度(CV): 0.220
# [865_1_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 10.305, 混乱度(CV): 0.268
# [865_2_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.84, 混乱度(CV): 0.276
# [865_3_det.jpg] 气孔: 252, 密度: 1.311e-04, 行数: 11.13, 混乱度(CV): 0.246
# [865_4_det.jpg] 气孔: 193, 密度: 1.004e-04, 行数: 8.915, 混乱度(CV): 0.238
# [866_1_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 11.055, 混乱度(CV): 0.216
# [866_2_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 11.955, 混乱度(CV): 0.228
# [866_3_det.jpg] 气孔: 256, 密度: 1.331e-04, 行数: 11.35, 混乱度(CV): 0.273
# [866_4_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 11.58, 混乱度(CV): 0.221
# [866_5_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 9.645, 混乱度(CV): 0.312
# [867_1_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 9.3, 混乱度(CV): 0.231
# [867_2_det.jpg] 气孔: 209, 密度: 1.087e-04, 行数: 9.44, 混乱度(CV): 0.252
# [867_3_det.jpg] 气孔: 200, 密度: 1.041e-04, 行数: 8.595, 混乱度(CV): 0.252
# [867_4_det.jpg] 气孔: 228, 密度: 1.186e-04, 行数: 9.55, 混乱度(CV): 0.236
# [867_5_det.jpg] 气孔: 181, 密度: 9.418e-05, 行数: 8.395, 混乱度(CV): 0.229
# [867_6_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 10.145, 混乱度(CV): 0.235
# [868_1_det.jpg] 气孔: 277, 密度: 1.441e-04, 行数: 11.6, 混乱度(CV): 0.205
# [868_2_det.jpg] 气孔: 302, 密度: 1.571e-04, 行数: 12.1, 混乱度(CV): 0.222
# [868_3_det.jpg] 气孔: 292, 密度: 1.519e-04, 行数: 12.125, 混乱度(CV): 0.254
# [868_4_det.jpg] 气孔: 315, 密度: 1.639e-04, 行数: 12.595, 混乱度(CV): 0.223
# [869_1_det.jpg] 气孔: 210, 密度: 1.093e-04, 行数: 8.81, 混乱度(CV): 0.305
# [869_2_det.jpg] 气孔: 215, 密度: 1.119e-04, 行数: 8.635, 混乱度(CV): 0.285
# [869_3_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 11.3, 混乱度(CV): 0.249
# [869_4_det.jpg] 气孔: 237, 密度: 1.232e-04, 行数: 10.055, 混乱度(CV): 0.284
# [870_1_det.jpg] 气孔: 205, 密度: 1.066e-04, 行数: 8.98, 混乱度(CV): 0.265
# [870_2_det.jpg] 气孔: 200, 密度: 1.041e-04, 行数: 8.99, 混乱度(CV): 0.230
# [870_3_det.jpg] 气孔: 172, 密度: 8.949e-05, 行数: 7.55, 混乱度(CV): 0.302
# [870_4_det.jpg] 气孔: 162, 密度: 8.429e-05, 行数: 7.29, 混乱度(CV): 0.270
# [870_5_det.jpg] 气孔: 200, 密度: 1.040e-04, 行数: 9.07, 混乱度(CV): 0.307
# [871_1_det.jpg] 气孔: 177, 密度: 9.210e-05, 行数: 7.93, 混乱度(CV): 0.292
# [871_2_det.jpg] 气孔: 213, 密度: 1.108e-04, 行数: 9.66, 混乱度(CV): 0.237
# [872_1_det.jpg] 气孔: 280, 密度: 1.457e-04, 行数: 11.525, 混乱度(CV): 0.229
# [872_2_det.jpg] 气孔: 255, 密度: 1.326e-04, 行数: 10.98, 混乱度(CV): 0.207
# [872_3_det.jpg] 气孔: 278, 密度: 1.446e-04, 行数: 11.865, 混乱度(CV): 0.200
# [872_4_det.jpg] 气孔: 327, 密度: 1.701e-04, 行数: 13.395, 混乱度(CV): 0.209
# [873_1_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 9.635, 混乱度(CV): 0.341
# [873_2_det.jpg] 气孔: 236, 密度: 1.227e-04, 行数: 10.575, 混乱度(CV): 0.368
# [873_3_det.jpg] 气孔: 240, 密度: 1.249e-04, 行数: 10.565, 混乱度(CV): 0.283
# [873_4_det.jpg] 气孔: 241, 密度: 1.254e-04, 行数: 10.775, 混乱度(CV): 0.224
# [874_1_det.jpg] 气孔: 226, 密度: 1.176e-04, 行数: 9.805, 混乱度(CV): 0.229
# [874_2_det.jpg] 气孔: 195, 密度: 1.015e-04, 行数: 8.475, 混乱度(CV): 0.218
# [874_3_det.jpg] 气孔: 212, 密度: 1.102e-04, 行数: 9.785, 混乱度(CV): 0.179
# [874_4_det.jpg] 气孔: 178, 密度: 9.267e-05, 行数: 7.66, 混乱度(CV): 0.177
# [875_1_det.jpg] 气孔: 188, 密度: 9.782e-05, 行数: 8.545, 混乱度(CV): 0.208
# [875_2_det.jpg] 气孔: 223, 密度: 1.160e-04, 行数: 8.78, 混乱度(CV): 0.183
# [875_3_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.865, 混乱度(CV): 0.215
# [875_4_det.jpg] 气孔: 190, 密度: 9.876e-05, 行数: 8.23, 混乱度(CV): 0.216
# [876_1_det.jpg] 气孔: 193, 密度: 1.004e-04, 行数: 9.03, 混乱度(CV): 0.287
# [876_2_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 9.325, 混乱度(CV): 0.289
# [876_3_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.375, 混乱度(CV): 0.273
# [876_4_det.jpg] 气孔: 195, 密度: 1.015e-04, 行数: 8.515, 混乱度(CV): 0.237
# [877_1_det.jpg] 气孔: 225, 密度: 1.171e-04, 行数: 10.095, 混乱度(CV): 0.243
# [877_2_det.jpg] 气孔: 248, 密度: 1.290e-04, 行数: 10.61, 混乱度(CV): 0.298
# [877_3_det.jpg] 气孔: 276, 密度: 1.436e-04, 行数: 11.995, 混乱度(CV): 0.254
# [877_4_det.jpg] 气孔: 261, 密度: 1.358e-04, 行数: 11.685, 混乱度(CV): 0.278
# [878_1_det.jpg] 气孔: 220, 密度: 1.145e-04, 行数: 9.85, 混乱度(CV): 0.238
# [878_2_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 9.57, 混乱度(CV): 0.210
# [878_3_det.jpg] 气孔: 246, 密度: 1.279e-04, 行数: 10.715, 混乱度(CV): 0.260
# [878_4_det.jpg] 气孔: 224, 密度: 1.166e-04, 行数: 9.435, 混乱度(CV): 0.240
# [879_1_det.jpg] 气孔: 351, 密度: 1.826e-04, 行数: 13.41, 混乱度(CV): 0.189
# [879_2_det.jpg] 气孔: 265, 密度: 1.379e-04, 行数: 11.075, 混乱度(CV): 0.211
# [879_3_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 11.0, 混乱度(CV): 0.219
# [879_4_det.jpg] 气孔: 339, 密度: 1.764e-04, 行数: 13.995, 混乱度(CV): 0.226
# [880_1_det.jpg] 气孔: 233, 密度: 1.212e-04, 行数: 9.71, 混乱度(CV): 0.236
# [880_2_det.jpg] 气孔: 286, 密度: 1.488e-04, 行数: 12.1, 混乱度(CV): 0.240
# [880_3_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 11.49, 混乱度(CV): 0.221
# [880_4_det.jpg] 气孔: 195, 密度: 1.015e-04, 行数: 8.32, 混乱度(CV): 0.227
# [881_1_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 9.02, 混乱度(CV): 0.316
# [881_2_det.jpg] 气孔: 222, 密度: 1.154e-04, 行数: 9.81, 混乱度(CV): 0.274
# [881_3_det.jpg] 气孔: 183, 密度: 9.522e-05, 行数: 8.57, 混乱度(CV): 0.345
# [881_4_det.jpg] 气孔: 178, 密度: 9.262e-05, 行数: 8.17, 混乱度(CV): 0.244
# [882_1_det.jpg] 气孔: 245, 密度: 1.275e-04, 行数: 10.31, 混乱度(CV): 0.333
# [882_2_det.jpg] 气孔: 215, 密度: 1.118e-04, 行数: 9.34, 混乱度(CV): 0.190
# [882_3_det.jpg] 气孔: 269, 密度: 1.400e-04, 行数: 11.34, 混乱度(CV): 0.250
# [883_1_det.jpg] 气孔: 279, 密度: 1.452e-04, 行数: 11.485, 混乱度(CV): 0.277
# [883_2_det.jpg] 气孔: 212, 密度: 1.103e-04, 行数: 9.825, 混乱度(CV): 0.230
# [884_1_det.jpg] 气孔: 255, 密度: 1.327e-04, 行数: 10.84, 混乱度(CV): 0.188
# [884_2_det.jpg] 气孔: 284, 密度: 1.478e-04, 行数: 11.97, 混乱度(CV): 0.215
# [884_3_det.jpg] 气孔: 253, 密度: 1.316e-04, 行数: 10.695, 混乱度(CV): 0.232
# [884_4_det.jpg] 气孔: 254, 密度: 1.322e-04, 行数: 10.53, 混乱度(CV): 0.210
# [885_1_det.jpg] 气孔: 214, 密度: 1.112e-04, 行数: 9.9, 混乱度(CV): 0.194
# [885_2_det.jpg] 气孔: 242, 密度: 1.260e-04, 行数: 10.915, 混乱度(CV): 0.290
# [885_3_det.jpg] 气孔: 222, 密度: 1.155e-04, 行数: 9.99, 混乱度(CV): 0.258
# [885_4_det.jpg] 气孔: 294, 密度: 1.530e-04, 行数: 12.355, 混乱度(CV): 0.255
# [886_1_det.jpg] 气孔: 191, 密度: 9.938e-05, 行数: 8.935, 混乱度(CV): 0.199
# [886_2_det.jpg] 气孔: 178, 密度: 9.262e-05, 行数: 8.815, 混乱度(CV): 0.235
# [886_3_det.jpg] 气孔: 284, 密度: 1.478e-04, 行数: 12.705, 混乱度(CV): 0.243
# [886_4_det.jpg] 气孔: 231, 密度: 1.202e-04, 行数: 10.44, 混乱度(CV): 0.320
# [887_1_det.jpg] 气孔: 226, 密度: 1.176e-04, 行数: 10.26, 混乱度(CV): 0.185
# [887_2_det.jpg] 气孔: 196, 密度: 1.020e-04, 行数: 8.795, 混乱度(CV): 0.198
# [887_3_det.jpg] 气孔: 250, 密度: 1.301e-04, 行数: 11.26, 混乱度(CV): 0.193
# [887_4_det.jpg] 气孔: 216, 密度: 1.124e-04, 行数: 9.41, 混乱度(CV): 0.202
# [888_1_det.jpg] 气孔: 309, 密度: 1.608e-04, 行数: 13.07, 混乱度(CV): 0.223
# [888_2_det.jpg] 气孔: 315, 密度: 1.639e-04, 行数: 13.215, 混乱度(CV): 0.234
# [888_3_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 11.01, 混乱度(CV): 0.247
# [888_4_det.jpg] 气孔: 242, 密度: 1.259e-04, 行数: 10.55, 混乱度(CV): 0.209
# [888_5_det.jpg] 气孔: 273, 密度: 1.420e-04, 行数: 11.8, 混乱度(CV): 0.214
# [889_1_det.jpg] 气孔: 274, 密度: 1.426e-04, 行数: 11.51, 混乱度(CV): 0.213
# [889_2_det.jpg] 气孔: 318, 密度: 1.655e-04, 行数: 13.035, 混乱度(CV): 0.219
# [889_3_det.jpg] 气孔: 238, 密度: 1.238e-04, 行数: 9.735, 混乱度(CV): 0.235
# [889_4_det.jpg] 气孔: 189, 密度: 9.834e-05, 行数: 8.435, 混乱度(CV): 0.215
# [906_1_det.jpg] 气孔: 202, 密度: 1.051e-04, 行数: 8.76, 混乱度(CV): 0.258
# [906_2_det.jpg] 气孔: 271, 密度: 1.410e-04, 行数: 11.135, 混乱度(CV): 0.245
# [970_1_det.jpg] 气孔: 208, 密度: 1.082e-04, 行数: 8.855, 混乱度(CV): 0.275
# [970_2_det.jpg] 气孔: 252, 密度: 1.310e-04, 行数: 10.44, 混乱度(CV): 0.247
# [970_3_det.jpg] 气孔: 237, 密度: 1.233e-04, 行数: 9.89, 混乱度(CV): 0.244
# [970_4_det.jpg] 气孔: 237, 密度: 1.233e-04, 行数: 10.545, 混乱度(CV): 0.300
# [970_5_det.jpg] 气孔: 257, 密度: 1.337e-04, 行数: 10.015, 混乱度(CV): 0.158
#
# 已处理 839 张图片，结果保存到 河南叶片气孔统计.csv

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import graycomatrix, graycoprops

# %%
def compute_glcm_features(
    img_gray, distances=[1], angles=[0, np.pi / 4, np.pi / 2, 3 * np.pi / 4], levels=256
):
    """
    计算灰度共生矩阵（GLCM）纹理特征，并对角度取平均
    返回 dict：contrast, dissimilarity, homogeneity, ASM, energy, correlation
    """
    # 生成 GLCM，normalize=True 归一化
    glcm = graycomatrix(
        img_gray,
        distances=distances,
        angles=angles,
        levels=levels,
        symmetric=True,
        normed=True,
    )
    props = ["contrast", "dissimilarity", "homogeneity", "ASM", "energy", "correlation"]
    feats = {}
    for p in props:
        vals = graycoprops(glcm, p)
        # vals.shape = (len(distances), len(angles))
        feats[p] = vals.mean()
    return feats


def process_folder(image_dir, output_csv="texture_features.csv"):
    records = []
    for fname in os.listdir(image_dir):
        if not fname.lower().endswith((".jpg", ".jpeg", ".png", ".tif", ".tiff")):
            continue
        path = os.path.join(image_dir, fname)
        # 1. 读取并灰度化
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"警告：无法读取 {fname}")
            continue
        # 2. 可选：尺寸标准化 / ROI 截取，根据需要
        # img = cv2.resize(img, (512,512))
        # 3. 量化到 8-bit（如果不是）
        if img.dtype != np.uint8:
            img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
        # 4. 计算纹理特征
        feats = compute_glcm_features(img)
        feats["image"] = fname
        records.append(feats)

    # 5. 保存为 CSV
    df = pd.DataFrame(records)
    df = df[
        [
            "image",
            "contrast",
            "dissimilarity",
            "homogeneity",
            "ASM",
            "energy",
            "correlation",
        ]
    ]
    df.to_csv(output_csv, index=False)
    print(f"已保存 {len(df)} 张图像的纹理特征到 {output_csv}")

# %%
if __name__ == "__main__":
    # 用户只需修改下面这一行
    IMAGE_FOLDER = "河南自交系穗位叶"
    process_folder(IMAGE_FOLDER, output_csv="河南叶片纹理特征.csv")
    IMAGE_FOLDER = "海南裁剪"
    process_folder(IMAGE_FOLDER, output_csv="海南叶片纹理特征.csv")
# Out:
# 已保存 839 张图像的纹理特征到 河南叶片纹理特征.csv
# 已保存 631 张图像的纹理特征到 海南叶片纹理特征.csv
